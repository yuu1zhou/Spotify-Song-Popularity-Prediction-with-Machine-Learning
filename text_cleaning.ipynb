# %%
import pandas as pd
import numpy as np

from unidecode import unidecode
import re

# %% [markdown]
# # Training dataset

# %%
df_train_cat = pd.read_csv("dataset/df_train_cat_rs_42.csv", index_col=0)
df_train_num = pd.read_csv("dataset/df_train_num_rs_42.csv", index_col=0)

df_train_cat = pd.concat([df_train_num.iloc[:, 0], df_train_cat], axis=1)

# %% [markdown]
# ## Text Cleaning
#
# There are songs appearing multiple times.

# %%
df_train_cat["track_name"].value_counts()
# Out:
# track_name
# Breathe                               18
# Alive                                 14
# Lost                                  13
# Poison                                13
# Dance Monkey                          12
#                                       ..
# Cold Hearted                           1
# ...Til the Cops Come Knockin'          1
# Espelho Meu - Ao Vivo                  1
# Sound Of The Future - Original Mix     1
# Merry Go Round                         1
# Name: count, Length: 16125, dtype: int64

# %% [markdown]
# An example of a song that appears multiple times in different albums and playlist.

# %%
df_train_cat.loc[df_train_cat[df_train_cat["track_name"] == "Poker Face"].index]
# Out:
#        track_popularity                track_id  track_name track_artist  \
# 2892                  6  6w1hZMlo2SVuq29liebhb8  Poker Face    Lady Gaga
# 2134                 55  70vvnTUamBXOc0vRk7BBDu  Poker Face    Lady Gaga
# 30083                42  4ngLDnC9X0ARJATJTXljdC  Poker Face    Lady Gaga
# 2548                 14  0le79px2kIBXQDxUe8ZUGP  Poker Face    Lady Gaga
# 20708                69  0WfKDYeUAoLA3vdvLKKWMW  Poker Face    Lady Gaga
#
#                track_album_id                         track_album_name  \
# 2892   482HqzMMfrkFXAGujtwFrm                               Poker Face
# 2134   7j7iPq5rokadGr1ZdJRGgE  The Fame Monster (International Deluxe)
# 30083  5drTYB3sPmtgLTnj04FUad                                 The Fame
# 2548   67j3NJodNRI8USUwKwTZA6  The Fame Monster (International Deluxe)
# 20708  2FBA8NCSuQNi8jaR2Xjbal                                 The Fame
#
#       track_album_release_date               playlist_name  \
# 2892                2008-09-26            Electropop - Pop
# 2134                2009-01-01               BALLARE - رقص
# 30083               2008-01-01          Pop Hits 2000-2019
# 2548                2009-01-01  Electropop Hits  2017-2020
# 20708               2008-01-01   Today's Hits 2000-Present
#
#                   playlist_id playlist_genre playlist_subgenre  key  mode
# 2892   5TiiHps0hNCyQ6ijVkNZQs            pop        electropop    4     1
# 2134   1CMvQ4Yr5DlYvYzI0Vc2UE            pop     post-teen pop    4     1
# 30083  6mtYuOxzl58vSGnEDtZ9uB            edm           pop edm    4     1
# 2548   7kyvBmlc1uSqsTL0EuNLrx            pop        electropop    4     1
# 20708  6a66cg3HcsjYkisYyQcov6          latin     latin hip hop    4     1

# %% [markdown]
# Duplicate entries can add noise to the dataset and harm model performance, so we keep only one record by keeping the one with the highest track popularity.

# %%
mask = df_train_cat.groupby("track_name")["track_popularity"].idxmax()
df_train_cat = df_train_cat.loc[mask]

# %% [markdown]
# ### 1. Song Title
#
# We notice that some song titles contain sub-information, which are in '( ... )' or behind '-', this type of information is usually about the featuring artists, remixing artists, remastered songs, sub-titles, and etc.

# %%
# title 结尾带 (...)
# title 结尾带 (... feat ...) 是 # title 结尾带 (...) 的 subset
process_df = df_train_cat[df_train_cat["track_name"].str.contains(r"\([^()]*\)\s*$", na=False)]
process_df.sample(10, random_state=42)
# Out:
#        track_popularity                track_id  \
# 6406                 10  43IfdE75ficQgsI8QGBvwb
# 11213                85  1wJRveJZLSb1rjhnUHQiv6
# 8147                 65  6HMHgBHdLBQ0QYIaOp2gse
# 2924                  3  48nmKZkd67ATPI8ROOJhkK
# 31967                56  1BmdqDrBU5eohtRwHBls6C
# 25612                46  2kYf8lZWXI4Ajd7ZhVhKhu
# 202                  48  6pu5jQqenr37n0z6eBKOh0
# 9325                 54  7pf6YT5CmmQxs6Uz7dABNB
# 7356                 66  1RjU7UhRICmdFPKxCucLgq
# 2353                 71  4YMqbFcDIFiCBd02PzUBcM
#
#                                               track_name  \
# 6406                   Mama/Show Love (feat. YBN Cordae)
# 11213                            Swervin (feat. 6ix9ine)
# 8147     I Don't Get Tired (#IDGT) (feat. August Alsina)
# 2924                                Lady (feat. Pitbull)
# 31967                                 joy. (R3HAB Remix)
# 25612                         YOU'RE THE ONE (feat. Syd)
# 202                     Dreams Of You (feat. Rae Morris)
# 9325   Doggy Dogg World (feat. The Dramatics & Tha Do...
# 7356                         Hell on Earth (Front Lines)
# 2353                            Thrift Shop (feat. Wanz)
#
#                   track_artist          track_album_id  \
# 6406                     Logic  6GeHCNwwqMMUrpxuGTRYcf
# 11213   A Boogie Wit da Hoodie  3r5hf3Cj3EMh1C2saQ8jyt
# 8147               Kevin Gates  4if4IsX36odNlcZF2kqgt3
# 2924             Austin Mahone  0PMO0t7hroaEi9A6SX15qZ
# 31967       for KING & COUNTRY  2gGMD56Y8DAvIzpoYfA014
# 25612               KAYTRANADA  3XmoA9zwTpg4VZJCcOGkNZ
# 202                     Icarus  26et8vS0ynfWtbIFKKtZi4
# 9325                Snoop Dogg  7f9KDGqY7X2VLBM5aA66KM
# 7356                 Mobb Deep  6BWf3fxsgSDhES4Cm4oyy5
# 2353   Macklemore & Ryan Lewis  6XO9dbsH9zhuQgFGH0hUrb
#
#                        track_album_name track_album_release_date  \
# 6406    Confessions of a Dangerous Mind               2019-05-10
# 11213                        Hoodie SZN               2018-12-21
# 8147       Luca Brasi 2: Gangsta Grillz               2014-12-15
# 2924                         For Me+You               2016-12-30
# 31967                joy. (R3HAB Remix)               2019-01-25
# 25612                             99.9%               2016-05-06
# 202    Dreams Of You (feat. Rae Morris)               2019-10-04
# 9325                         Doggystyle                     1993
# 7356           Hell On Earth (Explicit)               1996-11-19
# 2353                          The Heist               2012-10-10
#
#                                            playlist_name  \
# 6406                                       This Is Logic
# 11213                                     Trap Americana
# 8147                                             HIP&HOP
# 2924                                    Electropop - Pop
# 31967                    CHRISTIAN ELECTRO / DANCE / EDM
# 25612                                           NEO-soul
# 202                                           Dance Room
# 9325                                   90's Gangster Rap
# 7356   ◤ Hip Hop Dance Music – Urban – Trap – Breakin...
# 2353                                       post teen pop
#
#                   playlist_id playlist_genre          playlist_subgenre  key  \
# 6406   37i9dQZF1DWTIuAboZgTMf            rap                    hip hop    0
# 11213  7tkgK1tm9hYkWp7EFyOcAr            rap                       trap    9
# 8147   5DyJsJZOpMJh34WvUrQzMV            rap           southern hip hop    1
# 2924   5TiiHps0hNCyQ6ijVkNZQs            pop                 electropop   10
# 31967  0MhTMIo1bgH6zzPh7BdChT            edm  progressive electro house    0
# 25612  3q3M4VCymcMoxJ3Tl7mRqN            r&b                   neo soul    2
# 202    37i9dQZF1DX2ENAPP1Tyed            pop                  dance pop    6
# 9325   1g3APxk2mLVNU2TuHCPli0            rap               gangster rap    7
# 7356   0Hr2h94pKN8QAGVAgD6BsD            rap           southern hip hop    0
# 2353   6rjxP7GQKoqqgoakzxl3PY            pop              post-teen pop    6
#
#        mode
# 6406      0
# 11213     1
# 8147      1
# 2924      0
# 31967     0
# 25612     1
# 202       0
# 9325      1
# 7356      1
# 2353      0

# %%
# title 带 '-' 
df_train_cat[df_train_cat["track_name"].str.contains(r"-", case=False, na=False)].sample(10, random_state=42)
# Out:
#        track_popularity                track_id  \
# 24712                 5  4piae89WoVnwucdJzWrB7M
# 7583                 62  0jSMveIWvnhDIvzqN74Uc7
# 29014                12  2XjO02pppiExUbCmHyd94m
# 12320                16  4cCQ0wBIc9YHhvOWvWNj7S
# 12584                56  6n5lHdpuBDdA7pYDpiKzEI
# 28215                59  1q2yJEPlzwaJmDrXeof7z0
# 13565                52  36xEjbl8DtevPJgw6i9IuY
# 3550                  4  08smDzfxppUCFABj6FU2Xh
# 13851                29  0s1PewZjIU8DJqxktjeZaX
# 11332                53  7kipZd4tWx6Mu8kBgB2Z2r
#
#                                               track_name  \
# 24712                               O.P.P. (Re-Recorded)
# 7583                                    Tipsy - Club Mix
# 29014                              Universe - Radio Edit
# 12320  Hotel California - Live at The Los Angeles For...
# 12584                   Can't Get Enough - 2015 Remaster
# 28215                         LaLaLaLaLa - Gaullin Remix
# 13565          Feels like the First Time - 2008 Remaster
# 3550                                 Lebensborn - Update
# 13851       I Had a Dream, Joe - 2010 Remastered Version
# 11332                              God - Remastered 2010
#
#                     track_artist          track_album_id  \
# 24712          Naughty By Nature  6smksVgwxaPFGdSsIloCjo
# 7583                      J-Kwon  4yTlfDLsW1dK2kG1qoNsrv
# 29014                      THRML  2oSQAfsEnp4IYMXJomxP4x
# 12320                     Eagles  2A7TYsmTXaHAbQx6C3phKM
# 12584                Bad Company  4fuDpBLCt9ChDlqw48bj7p
# 28215                       Dwin  1whtnfVa5yF1Lozl3UgKHE
# 13565                  Foreigner  3RYi1mBYapOaGWQvwRjRjr
# 3550                    [:SITD:]  64Xx93nBRKzWuw2l26DC9p
# 13851  Nick Cave & The Bad Seeds  5WtxUsdAkyi39GlR9yhD1k
# 11332                John Lennon  0DFYbYCcHCEJPcN1hODG6K
#
#                                         track_album_name  \
# 24712                                        Anthem Inc.
# 7583                                            Hood Hop
# 29014                              Universe (Radio Edit)
# 12320  Hotel California (Live at The Los Angeles Foru...
# 12584                               Bad Company (Deluxe)
# 28215                         LaLaLaLaLa (Gaullin Remix)
# 13565  No End in Sight: The Very Best of Foreigner (E...
# 3550                                           Icon:Koru
# 13851            Henry's Dream (2010 Remastered Version)
# 11332                                   Plastic Ono Band
#
#       track_album_release_date  \
# 24712               2011-12-13
# 7583                      2004
# 29014               2019-10-18
# 12320                     1976
# 12584                     1974
# 28215               2017-09-04
# 13565                     2008
# 3550                2011-11-18
# 13851                     1992
# 11332               1970-12-11
#
#                                            playlist_name  \
# 24712  Back in the day - R&B, New Jack Swing, Swingbe...
# 7583                       The Sound of Southern Hip Hop
# 29014                  Sick Big Room House Drops | EZUMI
# 12320                                      Rock Classics
# 12584                               Classic Rock Workout
# 28215  🔊BASSBOOSTED🔊⚡ELECTRO HOUSE⚡🔥EDM CAR MUSIC2018...
# 13565                                 Classic Rock Radio
# 3550   Gothic / Industrial / Mittelalter / EBM / Futu...
# 13851                                     Permanent Wave
# 11332                                    The Black Album
#
#                   playlist_id playlist_genre playlist_subgenre  key  mode
# 24712  3a9y4eeCJRmG9p4YKfqYIx            r&b    new jack swing    4     0
# 7583   18jT9NMRZifv6cMtK2jWD4            rap  southern hip hop    0     1
# 29014  4R4c3WdN1Any2Q1NSuec3r            edm          big room    2     0
# 12320  37i9dQZF1DWXRqgorJj26U           rock      classic rock    2     1
# 12584  37i9dQZF1DWYNSm3Z3MxiM           rock      classic rock    0     1
# 28215  4GSiiL8tcMgvoV7K1IADb8            edm     electro house    4     0
# 13565  4lIywN6kXl9KPm3OQ8u8G7           rock      classic rock    7     1
# 3550   53CmFroG6MWR5reOOXJX6B            pop        electropop    8     1
# 13851  5Go0Jsxj1UnsU7Om841BEo           rock    permanent wave    7     0
# 11332  0KNLLunbFh9XgitPMOGmQg           rock        album rock    4     0

# %% [markdown]
# We only care about the main title, so we remove all the unnecessary information.
#
# Steps
#
# 1. Process the titles with '-'
#
# 2. Process the titles with '()'

# %%
df_train_cat["track_name"] = df_train_cat["track_name"].fillna("")
df_train_cat["track_album_name"] = df_train_cat["track_album_name"].fillna("")

df_train_cat["track_name"] = df_train_cat["track_name"].str.lower() # lowercase song title
df_train_cat["track_name"] = df_train_cat["track_name"].map(lambda x: unidecode(x)) # 处理类英文letter，至英文

print("Number of title with none English letter: ", df_train_cat["track_name"].str.contains(r"[^\x00-\x7F]+", regex=True).sum())
# Out:
# Number of title with none English letter:  0

# %%
# title 带 '-' 的一共 3591
process_df = df_train_cat[df_train_cat["track_name"].str.contains(r"-", case=False, na=False)]

print("\n rows: ", process_df.shape[0])
process_df.head()
# Out:
#  rows:  2645
#        track_popularity                track_id  \
# 10430                49  66HnjBqHKWinYBFkOBJkTs
# 14503                60  65NTcXUtOb27NHKQ4fAcw0
# 16760                51  1VpoazEusm1ki8hoSK49ua
# 16104                 1  6fZO4Uk2yM4MwrY13n2zBI
# 11758                76  2PzU4IB8Dr6mxV3lHuaG34
#
#                                          track_name        track_artist  \
# 10430                                   $$$ - remix        Saramalacara
# 14503                                '39 - 2011 mix               Queen
# 16760    '74 - '75 (feat. susan tyler) - radio edit    Paolo Pellegrino
# 16104      (don't fear) the reaper - single version    Blue Öyster Cult
# 11758  (i can't get no) satisfaction - mono version  The Rolling Stones
#
#                track_album_id  \
# 10430  42mpC1T2KCU8gCSXwB8bm0
# 14503  75eP8LZolyNBpqIRyB5pvB
# 16760  7IMYSlNJvGAztqUyPalK7C
# 16104  24atu8BmjlxBrHAS8aWQS1
# 11758  2Q5MwpTmtjscaS34mJFXQQ
#
#                                         track_album_name  \
# 10430                                        $$$ (Remix)
# 14503  A Night At The Opera (Deluxe Edition 2011 Rema...
# 16760                      '74 - '75 (feat. Susan Tyler)
# 16104                             The Singles Collection
# 11758                                   Out Of Our Heads
#
#       track_album_release_date                                  playlist_name  \
# 10430               2019-11-08                             Trapperz Argentina
# 14503               1975-11-21  I didn’t know perm stood for permanent (wave)
# 16760               2019-02-08                     Tropical House 🏝 2020 Hits
# 16104                     2005   Hard Rock Classics 1967-1991 (Party Edition)
# 11758               1965-07-30                        House Of The Rising Sun
#
#                   playlist_id playlist_genre playlist_subgenre  key  mode
# 10430  37i9dQZF1DWXrVH01e3PIE            rap              trap    1     0
# 14503  3e6gYPyrTbaB8BWgSHCt5j           rock    permanent wave    8     1
# 16760  2SRbIs0eBQwHeTP7kErjwo          latin          tropical   11     0
# 16104  1NIX36ZFWEtgXSbSNghoue           rock         hard rock    0     1
# 11758  1bMYfBHYBCRHY5LGkjlpSy           rock        album rock    2     1

# %%
pattern = r"-.*(mix|remaster|version|edit).*?$" # '- ... mix ...', '- ... remaster ...', '- ... version ...' , '- ... edit ...'
df_train_cat[df_train_cat["track_name"].str.contains(pattern, case = False, na = False)]
# Out:
# C:\Users\fuyuz\AppData\Local\Temp\ipykernel_13876\3990337827.py:2: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df_train_cat[df_train_cat["track_name"].str.contains(pattern, case = False, na = False)]
#        track_popularity                track_id  \
# 10430                49  66HnjBqHKWinYBFkOBJkTs
# 14503                60  65NTcXUtOb27NHKQ4fAcw0
# 16760                51  1VpoazEusm1ki8hoSK49ua
# 16104                 1  6fZO4Uk2yM4MwrY13n2zBI
# 11758                76  2PzU4IB8Dr6mxV3lHuaG34
# ...                 ...                     ...
# 28826                36  6tLnjekLODkxkRV4fWRv9z
# 14777                55  0zEKOcdfzNkvW1OFnazAQO
# 10160                43  7DqrY4tkiK3Nm1DLdYQ5NQ
# 426                  16  1RJPz4eFFP7N6VVKMYUS7O
# 26321                39  6AzSMF56Bce1YCaizQpzWH
#
#                                          track_name          track_artist  \
# 10430                                   $$$ - remix          Saramalacara
# 14503                                '39 - 2011 mix                 Queen
# 16760    '74 - '75 (feat. susan tyler) - radio edit      Paolo Pellegrino
# 16104      (don't fear) the reaper - single version      Blue Öyster Cult
# 11758  (i can't get no) satisfaction - mono version    The Rolling Stones
# ...                                             ...                   ...
# 28826            modern anxiety - banx & ranx remix          Josef Salvat
# 14777                  sugar honey ice & tea - edit  Bring Me The Horizon
# 10160                                wowowo - remix            chillwagon
# 426                    mizunonakahe - car tax remix             yu-re:meu
# 26321                         rabirinsu - album mix          Mondo Grosso
#
#                track_album_id  \
# 10430  42mpC1T2KCU8gCSXwB8bm0
# 14503  75eP8LZolyNBpqIRyB5pvB
# 16760  7IMYSlNJvGAztqUyPalK7C
# 16104  24atu8BmjlxBrHAS8aWQS1
# 11758  2Q5MwpTmtjscaS34mJFXQQ
# ...                       ...
# 28826  5IKaSJt6PKeXf6PdAP9icN
# 14777  2442fVHcs5gEuDXgRHespx
# 10160  07Qg40VH1l6gUBmsQb4n6e
# 426    03sSeRZnThaQK7SSsHhTSy
# 26321  3IhDlS0GsKJHNCcJA7xocM
#
#                                         track_album_name  \
# 10430                                        $$$ (Remix)
# 14503  A Night At The Opera (Deluxe Edition 2011 Rema...
# 16760                      '74 - '75 (feat. Susan Tyler)
# 16104                             The Singles Collection
# 11758                                   Out Of Our Heads
# ...                                                  ...
# 28826                 modern anxiety (Banx & Ranx Remix)
# 14777                       sugar honey ice & tea (Edit)
# 10160                                     wowowo - remix
# 426                                 Unstable Unstoppable
# 26321                                        何度でも新しく生まれる
#
#       track_album_release_date                                  playlist_name  \
# 10430               2019-11-08                             Trapperz Argentina
# 14503               1975-11-21  I didn’t know perm stood for permanent (wave)
# 16760               2019-02-08                     Tropical House 🏝 2020 Hits
# 16104                     2005   Hard Rock Classics 1967-1991 (Party Edition)
# 11758               1965-07-30                        House Of The Rising Sun
# ...                        ...                                            ...
# 28826               2019-12-12                               Dancefloor Beats
# 14777               2019-07-26                                      Rock Hard
# 10160               2019-08-26                                    Trap strefa
# 426                 2020-01-11                               Dance Pop: Japan
# 26321               2017-06-06               Japanese Funk/Soul/NEO/Jazz/Acid
#
#                   playlist_id playlist_genre playlist_subgenre  key  mode
# 10430  37i9dQZF1DWXrVH01e3PIE            rap              trap    1     0
# 14503  3e6gYPyrTbaB8BWgSHCt5j           rock    permanent wave    8     1
# 16760  2SRbIs0eBQwHeTP7kErjwo          latin          tropical   11     0
# 16104  1NIX36ZFWEtgXSbSNghoue           rock         hard rock    0     1
# 11758  1bMYfBHYBCRHY5LGkjlpSy           rock        album rock    2     1
# ...                       ...            ...               ...  ...   ...
# 28826  6mMk6QCzEgT3QGaCV1R4S5            edm          big room    2     1
# 14777  37i9dQZF1DWWJOmJ7nRx0C           rock         hard rock    0     0
# 10160  37i9dQZF1DWY3UKS6jvnxr            rap              trap   11     0
# 426    37i9dQZF1DXahYFr91pFvG            pop         dance pop    2     1
# 26321  4zNayWuATXCAA9gaXvnFnq            r&b          neo soul    6     1
#
# [2185 rows x 13 columns]

# %%
#'- ... mix ...', '- ... remaster ...', '- ... version ...' , '- ... edit ...' 占 带 '-' 的 proportion
print("Proportion of titles that have sub-title in the form of '- ... mix ...', '- ... remaster ...', '- ... version ...' , or '- ... edit ...': ",
      round(df_train_cat[df_train_cat["track_name"].str.contains(pattern, case = False, na = False)].shape[0] / df_train_cat[df_train_cat["track_name"].str.contains(r"-", case=False, na=False)].shape[0], 3)
      )
# Out:
# Proportion of titles that have sub-title in the form of '- ... mix ...', '- ... remaster ...', '- ... version ...' , or '- ... edit ...':  0.826
# C:\Users\fuyuz\AppData\Local\Temp\ipykernel_13876\1242914944.py:3: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   round(df_train_cat[df_train_cat["track_name"].str.contains(pattern, case = False, na = False)].shape[0] / df_train_cat[df_train_cat["track_name"].str.contains(r"-", case=False, na=False)].shape[0], 3)

# %% [markdown]
# 需要特殊处理的一组titl

# %%
process_df.loc[~ process_df["track_name"].str.contains(pattern, case = False, na = False)]
# Out:
# C:\Users\fuyuz\AppData\Local\Temp\ipykernel_13876\2356024891.py:1: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   process_df.loc[~ process_df["track_name"].str.contains(pattern, case = False, na = False)]
#        track_popularity                track_id  \
# 6421                 81  5tz69p7tJuGPeMGwNTxYuV
# 9567                  1  7CMAwm7mEkZkkaBl82DicE
# 31192                33  49rr7j8CCRq5ntOSTScupk
# 3162                 19  2upFJKo7EvWdMx5732mhuc
# 30346                73  01wavOnjFBNgdMWBFYIAP4
# ...                 ...                     ...
# 26344                26  2QIxieRCegkCSS2nDsBFRG
# 11428                30  4twOuEvYNHNUc9dHUqhhUY
# 26323                30  2FavFnagG4fHny2f6GSyhr
# 26362                24  59ec82BVYaafQKsam7SYId
# 445                  70  42tFTth2jcF7iSo0RBjfJF
#
#                                    track_name        track_artist  \
# 6421                           1-800-273-8255               Logic
# 9567   2 of amerikaz most wanted - (explicit)                2Pac
# 31192                             3am - tr377           Eli Brown
# 3162                             5 8 6 - live           New Order
# 30346                      50 vezes - ao vivo      Sorriso Maroto
# ...                                       ...                 ...
# 26344                 Jun noha-tohamarinburu-             オメガトライブ
# 11428        Lian niNi rete -crazy about you-        Junko Ohashi
# 26323        Chun hatowaniMu Jue meru - ver.2        Mondo Grosso
# 26362                          Zhu *modera-to  Masayoshi Takanaka
# 445                         pikabu peek-a-boo          Red Velvet
#
#                track_album_id  \
# 6421   1HiN2YXZcc3EjmVZ4WjfBk
# 9567   3oaGekoJ37K0waoYjDzaRr
# 31192  15IcffEIE3gIHkpimAN8Xj
# 3162   3mZDjow2ZIxfWewSXum1d8
# 30346  29zZdrNrxlZsolrlspfmDA
# ...                       ...
# 26344  6HM0SPu1eIv721SbsO8l3o
# 11428  10BIzys0QO4l9UQGay0iRI
# 26323  3IhDlS0GsKJHNCcJA7xocM
# 26362  19H1VDeB8hMPmpG9LVKtHM
# 445    0rvrbZvaDX5S9ZBhwOwFfH
#
#                                       track_album_name  \
# 6421                                         Everybody
# 9567                    The Best of 2Pac - Pt. 1: Thug
# 31192  Toolroom Radio EP377 - Presented By Mark Knight
# 3162                                     NOMC15 (Live)
# 30346                       Ao Cubo, Ao Vivo, Em Cores
# ...                                                ...
# 26344                                   River's Island
# 11428                   THE BEST SONGS of JUNKO OHASHI
# 26323                                      何度でも新しく生まれる
# 26362                     SUPER COLLECTION ~EMI Years~
# 445                     Perfect Velvet - The 2nd Album
#
#       track_album_release_date  \
# 6421                2017-05-05
# 9567                2007-12-04
# 31192               2017-06-16
# 3162                2017-12-01
# 30346               2019-03-29
# ...                        ...
# 26344               1984-03-21
# 11428                     1998
# 26323               2017-06-06
# 26362                     1985
# 445                 2017-11-17
#
#                                            playlist_name  \
# 6421                                       This Is Logic
# 9567                            Gangsta Rap/90's Hip-Hop
# 31192                                     Selected House
# 3162                                 Electropop And Play
# 30346  Verão 2020 | Pop | Funk | Sertanejo | EDM | To...
# ...                                                  ...
# 26344                   Japanese Funk/Soul/NEO/Jazz/Acid
# 11428                              City Pop 1985 シティーポップ
# 26323                   Japanese Funk/Soul/NEO/Jazz/Acid
# 26362                   Japanese Funk/Soul/NEO/Jazz/Acid
# 445                                    K-Party Dance Mix
#
#                   playlist_id playlist_genre          playlist_subgenre  key  \
# 6421   37i9dQZF1DWTIuAboZgTMf            rap                    hip hop    5
# 9567   62spXXfUxBed8nbd5xvH2O            rap               gangster rap    1
# 31192  2JPzPB9jnvJLAYtmCbvZy8            edm  progressive electro house    0
# 3162   7p30DzTAgW6OhspSXHTI88            pop                 electropop    5
# 30346  5HmZtuuIDMtIy21kylqhx6            edm                    pop edm    7
# ...                       ...            ...                        ...  ...
# 26344  4zNayWuATXCAA9gaXvnFnq            r&b                   neo soul    4
# 11428  3j2osvmecEao5nmo9jZ5df           rock                 album rock    5
# 26323  4zNayWuATXCAA9gaXvnFnq            r&b                   neo soul    1
# 26362  4zNayWuATXCAA9gaXvnFnq            r&b                   neo soul    1
# 445    37i9dQZF1DX4RDXswvP6Mj            pop                  dance pop    1
#
#        mode
# 6421      0
# 9567      1
# 31192     1
# 3162      0
# 30346     1
# ...     ...
# 26344     0
# 11428     0
# 26323     1
# 26362     0
# 445       0
#
# [460 rows x 13 columns]

# %% [markdown]
# 这些 index 是需要独立处理的

# %%
process_special_idx_lis = [24673, 5047, 9202, 13702, 6712, 5259, 7585, 11323, 11792, 9485, 32426, 2238, 26097, 1768, 26383, 6421, 410, 16902, 
                           11428, 13593, 29454, 7864, 12723, 23680, 14491, 4411, 27410, 9458, 8603, 15405, 20613, 11521, 7197, 4822, 8262, 8699, 
                           445, 19854, 15053, 18927, 14250, 5765, 9543, 25796, 10252, 23046, 754, 6158, 12026, 9551, 8991, 27330, 9696, 3235, 
                           19366, 9156, 9552, 9965, 12198, 14435, 6085, 25101, 818, 10976, 20648, 9479, 27092, 5785, 8963, 9533, 12861, 7995, 
                           30791, 9775, 16932, 8185, 6992, 6901, 3414, 11849, 20616, 5590, 442, 17709, 6317, 21121, 5782, 15463, 9160, 12046, 
                           26414, 12595, 24077, 6150, 27025, 8007, 24253]

len(process_special_idx_lis)

#remove_idx = [9202, 32426, 26097, 11521, 23046, 6158, 19366, 9156, 6992, 6317, 9160]
remove_idx = [9202, 32426, 26097, 6158, 19366, 9156, 6992, 6317, 9160,
              5259, 2238, 1768, 9458, 7197, 754, 27330, 14435, 30791, 9775, 16932, 8185, 442, 27025]
process_special_idx_lis = pd.Series(process_special_idx_lis)
process_special_idx_lis = process_special_idx_lis[~process_special_idx_lis.isin(remove_idx)].tolist()

# %%
process_df_sub = process_df[process_df["track_name"].str.contains(pattern, case = False, na = False)] # 直接去掉 ‘-’, row 3001
process_df_sub_1 = process_df.loc[~ process_df["track_name"].str.contains(pattern, case = False, na = False)] # 需特地处理, row 590
# Out:
# C:\Users\fuyuz\AppData\Local\Temp\ipykernel_13876\3495840086.py:1: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   process_df_sub = process_df[process_df["track_name"].str.contains(pattern, case = False, na = False)] # 直接去掉 ‘-’, row 3001
# C:\Users\fuyuz\AppData\Local\Temp\ipykernel_13876\3495840086.py:2: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   process_df_sub_1 = process_df.loc[~ process_df["track_name"].str.contains(pattern, case = False, na = False)] # 需特地处理, row 590

# %% [markdown]
# 处理 3410 row 的部分，直接去掉 含'-'后面的内容

# %%
process_df_sub
# Out:
#        track_popularity                track_id  \
# 10430                49  66HnjBqHKWinYBFkOBJkTs
# 14503                60  65NTcXUtOb27NHKQ4fAcw0
# 16760                51  1VpoazEusm1ki8hoSK49ua
# 16104                 1  6fZO4Uk2yM4MwrY13n2zBI
# 11758                76  2PzU4IB8Dr6mxV3lHuaG34
# ...                 ...                     ...
# 28826                36  6tLnjekLODkxkRV4fWRv9z
# 14777                55  0zEKOcdfzNkvW1OFnazAQO
# 10160                43  7DqrY4tkiK3Nm1DLdYQ5NQ
# 426                  16  1RJPz4eFFP7N6VVKMYUS7O
# 26321                39  6AzSMF56Bce1YCaizQpzWH
#
#                                          track_name          track_artist  \
# 10430                                   $$$ - remix          Saramalacara
# 14503                                '39 - 2011 mix                 Queen
# 16760    '74 - '75 (feat. susan tyler) - radio edit      Paolo Pellegrino
# 16104      (don't fear) the reaper - single version      Blue Öyster Cult
# 11758  (i can't get no) satisfaction - mono version    The Rolling Stones
# ...                                             ...                   ...
# 28826            modern anxiety - banx & ranx remix          Josef Salvat
# 14777                  sugar honey ice & tea - edit  Bring Me The Horizon
# 10160                                wowowo - remix            chillwagon
# 426                    mizunonakahe - car tax remix             yu-re:meu
# 26321                         rabirinsu - album mix          Mondo Grosso
#
#                track_album_id  \
# 10430  42mpC1T2KCU8gCSXwB8bm0
# 14503  75eP8LZolyNBpqIRyB5pvB
# 16760  7IMYSlNJvGAztqUyPalK7C
# 16104  24atu8BmjlxBrHAS8aWQS1
# 11758  2Q5MwpTmtjscaS34mJFXQQ
# ...                       ...
# 28826  5IKaSJt6PKeXf6PdAP9icN
# 14777  2442fVHcs5gEuDXgRHespx
# 10160  07Qg40VH1l6gUBmsQb4n6e
# 426    03sSeRZnThaQK7SSsHhTSy
# 26321  3IhDlS0GsKJHNCcJA7xocM
#
#                                         track_album_name  \
# 10430                                        $$$ (Remix)
# 14503  A Night At The Opera (Deluxe Edition 2011 Rema...
# 16760                      '74 - '75 (feat. Susan Tyler)
# 16104                             The Singles Collection
# 11758                                   Out Of Our Heads
# ...                                                  ...
# 28826                 modern anxiety (Banx & Ranx Remix)
# 14777                       sugar honey ice & tea (Edit)
# 10160                                     wowowo - remix
# 426                                 Unstable Unstoppable
# 26321                                        何度でも新しく生まれる
#
#       track_album_release_date                                  playlist_name  \
# 10430               2019-11-08                             Trapperz Argentina
# 14503               1975-11-21  I didn’t know perm stood for permanent (wave)
# 16760               2019-02-08                     Tropical House 🏝 2020 Hits
# 16104                     2005   Hard Rock Classics 1967-1991 (Party Edition)
# 11758               1965-07-30                        House Of The Rising Sun
# ...                        ...                                            ...
# 28826               2019-12-12                               Dancefloor Beats
# 14777               2019-07-26                                      Rock Hard
# 10160               2019-08-26                                    Trap strefa
# 426                 2020-01-11                               Dance Pop: Japan
# 26321               2017-06-06               Japanese Funk/Soul/NEO/Jazz/Acid
#
#                   playlist_id playlist_genre playlist_subgenre  key  mode
# 10430  37i9dQZF1DWXrVH01e3PIE            rap              trap    1     0
# 14503  3e6gYPyrTbaB8BWgSHCt5j           rock    permanent wave    8     1
# 16760  2SRbIs0eBQwHeTP7kErjwo          latin          tropical   11     0
# 16104  1NIX36ZFWEtgXSbSNghoue           rock         hard rock    0     1
# 11758  1bMYfBHYBCRHY5LGkjlpSy           rock        album rock    2     1
# ...                       ...            ...               ...  ...   ...
# 28826  6mMk6QCzEgT3QGaCV1R4S5            edm          big room    2     1
# 14777  37i9dQZF1DWWJOmJ7nRx0C           rock         hard rock    0     0
# 10160  37i9dQZF1DWY3UKS6jvnxr            rap              trap   11     0
# 426    37i9dQZF1DXahYFr91pFvG            pop         dance pop    2     1
# 26321  4zNayWuATXCAA9gaXvnFnq            r&b          neo soul    6     1
#
# [2185 rows x 13 columns]

# %%
def strip_leading_paren(title: str) -> str:
    cleaned = re.sub(r"^\s*\([^)]*\)\s*", "", title)
    return cleaned


def clean_title_part_1(column): # pd df column, 替换 '-' to ''

    column = column.str.replace(r"\s*-\s*.*$", "", regex=True)
    column = column.map(strip_leading_paren) # 先去掉 () 在开头的title
    column = column.str.replace("'", "")
    column = column.str.replace(r"\s*\(.*$", "", regex=True) # 去掉 ( 以及后面的内容
    column = column.str.replace(r"[?.,'&`]", "", regex=True) #  去除 ? , . ' & ` 
    column = column.str.replace(r"[!:]$", "", regex=True) # 去掉紧跟的 ! 和 :, : 匹配不到
    column = column.str.replace(r":", "", regex=True)
    column = column.str.replace(r"\s*\[[^\]]*\]", "", regex=True) # 移除 [...]
    column = column.str.replace(r"#\d+", "", regex=True) # 移除 #number

    column = column.str.replace(r"\s{2,}", " ", regex=True) # 两步把多余空格压成一个

    column = column.str.strip()

    return column

process_df_sub.loc[:, "track_name"] = clean_title_part_1(process_df_sub.loc[:, "track_name"])

# %% [markdown]
# 分为 special 和 non-special

# %%
process_df_sub_1_special = process_df_sub_1.loc[process_special_idx_lis] # row 97
process_df_sub_1_non_special = process_df_sub_1.loc[~ process_df_sub_1.index.isin(process_special_idx_lis)] # row 493

# %%
process_df_sub_1_non_special
# Out:
#        track_popularity                track_id  \
# 9567                  1  7CMAwm7mEkZkkaBl82DicE
# 31192                33  49rr7j8CCRq5ntOSTScupk
# 3162                 19  2upFJKo7EvWdMx5732mhuc
# 30346                73  01wavOnjFBNgdMWBFYIAP4
# 379                  48  4suDPyEfKYtqDR2OGblbTi
# ...                 ...                     ...
# 9474                  8  1D7FQQfKf4o3Xd2QTm1441
# 1030                 37  5VRtz5coFkV9EqVLGEsg6k
# 26344                26  2QIxieRCegkCSS2nDsBFRG
# 26323                30  2FavFnagG4fHny2f6GSyhr
# 26362                24  59ec82BVYaafQKsam7SYId
#
#                                               track_name         track_artist  \
# 9567              2 of amerikaz most wanted - (explicit)                 2Pac
# 31192                                        3am - tr377            Eli Brown
# 3162                                        5 8 6 - live            New Order
# 30346                                 50 vezes - ao vivo       Sorriso Maroto
# 379    9to4Fen no3Fan Xian deJun woDai tsu (run away)...  TOMORROW X TOGETHER
# ...                                                  ...                  ...
# 9474                          musi pusi 2 - fenomenbeats       Сережа Местный
# 1030                                       garireo*ga-ru          NONA REEVES
# 26344                            Jun noha-tohamarinburu-              オメガトライブ
# 26323                   Chun hatowaniMu Jue meru - ver.2         Mondo Grosso
# 26362                                     Zhu *modera-to   Masayoshi Takanaka
#
#                track_album_id  \
# 9567   3oaGekoJ37K0waoYjDzaRr
# 31192  15IcffEIE3gIHkpimAN8Xj
# 3162   3mZDjow2ZIxfWewSXum1d8
# 30346  29zZdrNrxlZsolrlspfmDA
# 379    0q7bDr9lPLduHdECJOYZ8B
# ...                       ...
# 9474   3oG2yCj5yUHdKOUgKBoZPR
# 1030   1anEfewz5CYK3KQlQYysKc
# 26344  6HM0SPu1eIv721SbsO8l3o
# 26323  3IhDlS0GsKJHNCcJA7xocM
# 26362  19H1VDeB8hMPmpG9LVKtHM
#
#                                       track_album_name  \
# 9567                    The Best of 2Pac - Pt. 1: Thug
# 31192  Toolroom Radio EP377 - Presented By Mark Knight
# 3162                                     NOMC15 (Live)
# 30346                       Ao Cubo, Ao Vivo, Em Cores
# 379                                         MAGIC HOUR
# ...                                                ...
# 9474                                       Попеременно
# 1030                                                未来
# 26344                                   River's Island
# 26323                                      何度でも新しく生まれる
# 26362                     SUPER COLLECTION ~EMI Years~
#
#       track_album_release_date  \
# 9567                2007-12-04
# 31192               2017-06-16
# 3162                2017-12-01
# 30346               2019-03-29
# 379                 2020-01-14
# ...                        ...
# 9474                2013-11-11
# 1030                2019-03-13
# 26344               1984-03-21
# 26323               2017-06-06
# 26362                     1985
#
#                                            playlist_name  \
# 9567                            Gangsta Rap/90's Hip-Hop
# 31192                                     Selected House
# 3162                                 Electropop And Play
# 30346  Verão 2020 | Pop | Funk | Sertanejo | EDM | To...
# 379                                     Dance Pop: Japan
# ...                                                  ...
# 9474                                RUSSIAN Gangster Rap
# 1030                       Best of 2019 Dance Pop: Japan
# 26344                   Japanese Funk/Soul/NEO/Jazz/Acid
# 26323                   Japanese Funk/Soul/NEO/Jazz/Acid
# 26362                   Japanese Funk/Soul/NEO/Jazz/Acid
#
#                   playlist_id playlist_genre          playlist_subgenre  key  \
# 9567   62spXXfUxBed8nbd5xvH2O            rap               gangster rap    1
# 31192  2JPzPB9jnvJLAYtmCbvZy8            edm  progressive electro house    0
# 3162   7p30DzTAgW6OhspSXHTI88            pop                 electropop    5
# 30346  5HmZtuuIDMtIy21kylqhx6            edm                    pop edm    7
# 379    37i9dQZF1DXahYFr91pFvG            pop                  dance pop    1
# ...                       ...            ...                        ...  ...
# 9474   0Jw0HckkxCfIrOvpN081eV            rap               gangster rap    1
# 1030   37i9dQZF1DXdOtZGKonFlM            pop                  dance pop    9
# 26344  4zNayWuATXCAA9gaXvnFnq            r&b                   neo soul    4
# 26323  4zNayWuATXCAA9gaXvnFnq            r&b                   neo soul    1
# 26362  4zNayWuATXCAA9gaXvnFnq            r&b                   neo soul    1
#
#        mode
# 9567      1
# 31192     1
# 3162      0
# 30346     1
# 379       1
# ...     ...
# 9474      1
# 1030      1
# 26344     0
# 26323     1
# 26362     0
#
# [386 rows x 13 columns]

# %% [markdown]
# 处理 special

# %%
def clean_title_part_2(column): # pd df column, 替换 '-' to ''
    column = column.str.replace("-", " ")
    column = column.str.replace(r"'s\b", "", regex=True) # "'s\b" 用单词边界确保只命中真正的缩写，不会误删 songs 里的 s。
    column = column.str.replace(r"[()?,.'/]", "", regex=True) #  去除 ( ) ? , . 
    column = column.str.replace(r"\s{2,}", " ", regex=True) # 两步把多余空格压成一个
    column = column.str.strip()

    return column

process_df_sub_1_special.loc[:,"track_name"] = clean_title_part_2(process_df_sub_1_special.loc[:,"track_name"])

# %% [markdown]
# 处理 non-special

# %%
def clean_title_part_3(column): # pd df column, 替换 '-' to ''

    column = column.str.replace(r"\s*-\s*.*$", "", regex=True)
    column = column.str.replace("'", "")
    column = column.str.replace(r"\s*\(.*$", "", regex=True) # 去掉 ( 以及后面的内容
    column = column.str.replace(r"[?.,'&]", "", regex=True) #  去除 ? , . ' & 
    column = column.str.replace(r"\s{2,}", " ", regex=True) # 两步把多余空格压成一个
    column = column.str.strip()

    return column

process_df_sub_1_non_special.loc[:,"track_name"] = clean_title_part_3(process_df_sub_1_non_special.loc[:,"track_name"])

# %% [markdown]
# 转移到 process_df

# %%
process_df.loc[process_df_sub.index, "track_name"] = process_df_sub["track_name"]
process_df.loc[process_df_sub_1_special.index, "track_name"] = process_df_sub_1_special["track_name"]
process_df.loc[process_df_sub_1_non_special.index, "track_name"] = process_df_sub_1_non_special["track_name"]

df_train_cat.loc[process_df.index, "track_name"] = process_df["track_name"] #转移到 df_train_cat

# %%
pattern = r"[^\w\s]"  # 非字母数字、非空白的字符
punctu_lis = df_train_cat.loc[~ df_train_cat["track_name"].str.contains(r"[()]", regex=True), "track_name"].str.findall(pattern).explode().unique()
punctu_lis = punctu_lis[1:]
punctu_lis
# Out:
# array(['.', '#', '$', nan, "'", '*', '+', '/', '%', ':', '[', ']', '@',
#        ',', '&', '!', '?', '`', '~', '|'], dtype=object)

# %%
def clean_title_part_4(column): # pd df column, 替换 '-' to ''

    column = column.map(strip_leading_paren) # 先去掉 () 在开头的title
    column = column.str.replace(r"\(([A-Za-z])\)", r"\1", regex=True) # d(r)own to drown
    column = column.str.replace(r"\s*\([^)]*\)", "", regex=True) # 去掉 (...) 以及后面的内容
    column = column.str.replace(r"[)]+$", "", regex=True) # 去掉 () 残余
    column = column.str.replace(r"\s*\[[^\]]*\]", "", regex=True) # 移除 [...]
    column = column.str.replace(r"\s*\[.*$", "", regex=True) # 移除残留 [...
    column = column.str.replace("'", "")
    column = column.str.replace(r"[?.!,&%+`\":~|<>]", "", regex=True) #  去除 ? . ! , & % + " : ~ | < >
    column = column.str.replace(r"[/]", " ", regex=True) 
    column = column.str.replace(r"#\d+", "", regex=True) # 去除 # + 数字 e.g. #1, #2, ...
    column = column.str.replace("#", "", regex=False) 

    column = column.str.replace(r"\s{2,}", " ", regex=True) # 两步把多余空格压成一个
    column = column.str.strip()

    return column

df_train_cat.loc[:, "track_name"] = clean_title_part_4(df_train_cat.loc[:, "track_name"])

# %%
punctu_lis
# Out:
# array(['.', '#', '$', nan, "'", '*', '+', '/', '%', ':', '[', ']', '@',
#        ',', '&', '!', '?', '`', '~', '|'], dtype=object)

# %%
df_train_cat.loc[~ df_train_cat["track_name"].str.contains(r"[()]", regex=True), "track_name"].str.findall(pattern).explode().unique()
# Out:
# array([nan, '$', '*', '@'], dtype=object)

# %% [markdown]
# 处理 $

# %%
df_train_cat.loc[df_train_cat["track_name"].str.contains("$", regex=False), "track_name"]
# Out:
# 10430                                            $$$
# 12685                                       $20 fine
# 5223                                         $dreams
# 23318                                 $ave dat money
# 10253                                           a$ap
# 8270                                    a$ap forever
# 18393                                      a$ian boy
# 22319                                      dat $tick
# 25756                                       love$ick
# 8316                                              m$
# 27548    midnight hour with boys noize ty dolla $ign
# 9259                          sie wollen meine loui$
# 3128                                           wing$
# 19515                                      cuanto e$
# Name: track_name, dtype: object

# %%
skip_idx = [10430, 5223, 12685]

mask = ~df_train_cat.index.isin(skip_idx)
df_train_cat.loc[mask, "track_name"] = df_train_cat.loc[mask, "track_name"].str.replace("$", "s", regex=False)

#df_train_cat.loc[21143, "track_name"] = df_train_cat.loc[21143, "track_name"].replace(" ", "")
df_train_cat.loc[skip_idx[1:], "track_name"] = df_train_cat.loc[skip_idx[1:], "track_name"].str.replace("$", "", regex=False)

# %% [markdown]
# 处理 *

# %%
process_df = df_train_cat[df_train_cat["track_name"].str.contains("*", regex=False)]

# %%
def expand_stars(text):
    # 每匹配到一段，repl 会被调用一次，match 就是这段匹配对象
    # match.group(0) 取出整段星号（比如 "*", "**", "***"）
    def repl(match): 
        stars = match.group(0)
        k = len(stars)
        return {1: "u", 2: "uc", 3: "uck"}.get(k, stars)

    return re.sub(r"\*{1,3}", repl, text)

pattern = r"f\*+(?:ck)?k?"
process_df.loc[process_df["track_name"].str.contains(pattern, regex=True), "track_name"]= process_df.loc[process_df["track_name"].str.contains(pattern, regex=True), "track_name"].map(expand_stars)

process_df.loc[6541, "track_name"] = re.sub(r"[*]", "i", process_df.loc[6541, "track_name"])
process_df.loc[[9206, 27122], "track_name"] = process_df.loc[[9206, 27122], "track_name"].str.replace(r"\*\*\*", "hit", regex=True)

process_df.loc[8790, "track_name"] = re.sub(r"\*\*", "gg", process_df.loc[8790, "track_name"])
process_df.loc[8782, "track_name"] = re.sub(r"\*\*\*\*", "igga", process_df.loc[8782, "track_name"])
process_df.loc[6183, "track_name"] = re.sub(r"[*]", "i", process_df.loc[6183, "track_name"])

process_df.loc[21930, "track_name"] = re.sub(r"[*]", "u", process_df.loc[21930, "track_name"])
process_df.loc[24620, "track_name"] = re.sub(r"(?<=a)\*\*", "ss", process_df.loc[24620, "track_name"])
process_df.loc[24620, "track_name"] = re.sub(r"\*\*", "it", process_df.loc[24620, "track_name"])
process_df.loc[25285, "track_name"] = re.sub(r"[*]", "i", process_df.loc[25285, "track_name"])

# %%
process_df.loc[:,"track_name"] = process_df.loc[:,"track_name"].str.replace("*", " ")
process_df.loc[:,"track_name"] = process_df.loc[:,"track_name"].str.replace(r"\s{2,}", " ", regex=True) # 两步把多余空格压成一个
process_df.loc[:,"track_name"] = process_df.loc[:,"track_name"].str.strip()

df_train_cat.loc[process_df.index, "track_name"] = process_df["track_name"] #转移到 df_train_cat

# %% [markdown]
# @ 保留, df_train_cat text cleaning done.

# %% [markdown]
# ### 2. Album name

# %%
df_train_cat.loc[:, "track_album_name"] = df_train_cat.loc[:, "track_album_name"].str.lower()
df_train_cat.loc[:, "track_album_name"] = df_train_cat.loc[:, "track_album_name"].map(lambda x: unidecode(x))

print("Number of album name with none English letter: ", df_train_cat["track_album_name"].str.contains(r"[^\x00-\x7F]+", regex=True).sum())
# Out:
# Number of album name with none English letter:  0

# %%
pattern = r"[^\w\s]" 
punctu_lis = df_train_cat["track_album_name"].str.findall(pattern).explode().unique()
#punctu_lis = punctu_lis[1:]
punctu_lis
# Out:
# array([nan, '#', '(', ')', '[', '.', ']', '$', "'", '-', ':', '&', '%',
#        '|', '@', '*', '+', '?', '!', '/', ',', '"', '`', ';', '~', '>'],
#       dtype=object)

# %%
def clean_album_name(column): # pd df column, 替换 '-' to ''

    column = column.map(strip_leading_paren) # 先去掉 () 在开头的title
    column = column.str.replace(r"\s*\([^)]*\)", "", regex=True) # 去掉 (...) 以及后面的内容
    column = column.str.replace(r"\s*\(.*$", "", regex=True) # 去掉 (... 残留
    column = column.str.replace(r"\s*\[[^\]]*\]", "", regex=True) # 移除 [...]
    column = column.str.replace(r"\s*\[.*$", "", regex=True) # 移除 [... 残留
    column = column.str.replace(r"\s*remix\)\s*$", "", regex=True) # 去掉 remix)

    column = column.str.replace(r"(?<=\b[A-Za-z])\.(?=[A-Za-z]\b)", "", regex=True) # 多一步处理 . , 处理 r.o.s.e 这样的
    column = column.str.replace(r"[-:>/.]", " ", regex=True)
    column = column.str.replace(r'''[?!,'"%+`~|<>{}=)]''', "", regex=True)
    column = column.str.replace(r"#\d+", "", regex=True) # 去除 # + 数字 e.g. #1, #2, ...
    column = column.str.replace("#", "", regex=False) 

    column = column.str.replace(r"\s{2,}", " ", regex=True) # 两步把多余空格压成一个
    column = column.str.strip()

    return column

df_train_cat.loc[:, "track_album_name"] = clean_album_name(df_train_cat.loc[:, "track_album_name"])

# %%
df_train_cat.loc[:, "track_album_name"].str.findall(pattern).explode().unique()
# Out:
# array([nan, '$', '&', '@', '*'], dtype=object)

# %% [markdown]
# $ *
#
# 专门处理 &
#
# @ 保留

# %% [markdown]
# 处理 &，只保留 r&b

# %%
mask = df_train_cat["track_album_name"].str.contains(r"(?i)r&b", regex=True)

df_train_cat.loc[~mask, "track_album_name"] = (
df_train_cat.loc[~mask, "track_album_name"]
       .str.replace("&", " ", regex=False)
     .str.replace(r"\s{2,}", " ", regex=True)
        .str.strip()
)

# %% [markdown]
# 处理 $, 换成 s

# %%
skip_idx = [10430]

mask = ~df_train_cat.index.isin(skip_idx)
df_train_cat.loc[mask, "track_album_name"] = df_train_cat.loc[mask, "track_album_name"].str.replace("$", "s", regex=False)

# %% [markdown]
# 处理 *

# %%
process_df = df_train_cat[df_train_cat["track_album_name"].str.contains("*", regex=False)]

pattern = r"f\*+(?:ck)?k?"
process_df.loc[process_df["track_album_name"].str.contains(pattern, regex=True), "track_album_name"]= process_df.loc[process_df["track_album_name"].str.contains(pattern, regex=True), "track_album_name"].map(expand_stars)

process_df.loc[[26330, 6496, 1040, 26329], "track_album_name"] = process_df.loc[[26330, 6496, 1040, 26329], "track_album_name"].str.replace(r"[*]", " ", regex=True)

process_df.loc[[9206, 27122], "track_album_name"] = process_df.loc[[9206, 27122], "track_album_name"].str.replace(r"\*\*\*", "hit", regex=True)

process_df.loc[21930, "track_album_name"] = re.sub(r"[*]", "u", process_df.loc[21930, "track_album_name"])
process_df.loc[6183, "track_album_name"] = re.sub(r"[*]", "i", process_df.loc[6183, "track_album_name"])

df_train_cat.loc[process_df.index, "track_album_name"] = process_df.loc[:, "track_album_name"]

# %% [markdown]
# ### 3. genre and sub-genre

# %%
def clean_genre(column): # 确保没有多余的空格

    column = column.str.replace(r"[-]", " ", regex = True) # 对 sub genre

    column = column.str.replace(r"\s{2,}", " ", regex=True) # 两步把多余空格压成一个
    column = column.str.strip()

    return column

df_train_cat.loc[:, "playlist_genre"] = clean_genre(df_train_cat.loc[:, "playlist_genre"])
df_train_cat.loc[:, "playlist_subgenre"] = clean_genre(df_train_cat.loc[:, "playlist_subgenre"])

# %% [markdown]
# ### Concatenate All the Texts

# %%
text_cols = df_train_cat.columns[[2, 5, 9, 10]]

for i in text_cols:
    print(f"{i} na number: ", df_train_cat[i].isna().sum())
print("")
for i in text_cols:
    print(f"0 length string in {i}: ", 0 in df_train_cat[i].str.len().values)
# Out:
# track_name na number:  0
# track_album_name na number:  0
# playlist_genre na number:  0
# playlist_subgenre na number:  0
#
# 0 length string in track_name:  True
# 0 length string in track_album_name:  True
# 0 length string in playlist_genre:  False
# 0 length string in playlist_subgenre:  False

# %%
df_train_cat["combined_text"] = (df_train_cat[text_cols].agg(" ".join, axis=1) # str concatenate
                                 .str.replace(r"\s{2,}", " ", regex=True)
                                 .str.strip())

# %% [markdown]
# ### Output

# %%
df_train_cat.to_csv("dataset/df_train_cat_rs_42_processed.csv", index=True, encoding="utf-8")

# %% [markdown]
# # Testing dataset

# %%
df_test_cat = pd.read_csv("dataset/df_test_cat_rs_42.csv", index_col=0)
df_test_num = pd.read_csv("dataset/df_test_num_rs_42.csv", index_col=0)

df_test_cat = pd.concat([df_test_num.iloc[:, 0], df_test_cat], axis=1)

# %%
df_test_cat.head()
# Out:
#        track_popularity                track_id    track_name    track_artist  \
# 30056                45  697MjF1454XKvZmTuqkWmD    I Miss You          Jeriqo
# 11827                17  3x2bXiU0o4WbsPkawXlfDA   Who Are You         The Who
# 23571                30  0jEaPBjFAWjQTMVouRwaHi         Happy  The Beef Seeds
# 14741                35  5EKUb1FKsyYVaSXb41YBIj           ONE      Rev Theory
# 25570                62  300DUx4tdtCdGEUXR032jA  Palace/Curse    The Internet
#
#                track_album_id          track_album_name  \
# 30056  2vJ6FDg6ZMS56U8Wbiw2Oz                I Miss You
# 11827  6LRJF97hgXHj8uMLHyCDbh  Who Are You (Remastered)
# 23571  4IQn9XpweytNX2cUe2NBUH          Keepin' it Beefy
# 14741  0gGic19XvEiHKKWBV7M4YM                       ONE
# 25570  69g3CtOVg98TPOwqmI2K7Q                 Ego Death
#
#       track_album_release_date            playlist_name  \
# 30056               2019-02-05       Pop Hits 2000-2019
# 11827               1978-08-18  House Of The Rising Sun
# 23571               2015-01-19         Bluegrass Covers
# 14741               2020-01-15                Rock Hard
# 25570               2015-06-26                 NEO-soul
#
#                   playlist_id playlist_genre playlist_subgenre  key  mode
# 30056  6mtYuOxzl58vSGnEDtZ9uB            edm           pop edm    0     1
# 11827  1bMYfBHYBCRHY5LGkjlpSy           rock        album rock    9     1
# 23571  37i9dQZF1DX56crgoe4TG3            r&b           hip pop   10     1
# 14741  37i9dQZF1DWWJOmJ7nRx0C           rock         hard rock    4     0
# 25570  3q3M4VCymcMoxJ3Tl7mRqN            r&b          neo soul   10     0

# %%
mask = df_test_cat.groupby("track_name")["track_popularity"].idxmax()
df_test_cat = df_test_cat.loc[mask]

# %% [markdown]
# ## Text Cleaning

# %% [markdown]
# ### 1. Song Title

# %%
# title 结尾带 (...)
# title 结尾带 (... feat ...) 是 # title 结尾带 (...) 的 subset
process_df = df_test_cat[df_test_cat["track_name"].str.contains(r"\([^()]*\)\s*$", na=False)]
process_df.sample(10, random_state=42)
# Out:
#        track_popularity                track_id  \
# 23282                85  7ef4DlsgrMEH11cDZd32M6
# 5953                 72  0W9E3s2G4szLUwXsE17x5E
# 5135                 74  46lFttIf5hnUZMGvjK0Wxo
# 8658                 45  48tybOd2kxWaMjnYrEWTvY
# 20129                85  2IRZnDFmlqMuOrYOLnZZyc
# 747                  10  3a94DkjR4idw3bp8yzai59
# 4981                 30  689izEMmyU0vp280Y0JLMl
# 345                  50  0FC7eAz8CW9HAWnBr8Yo42
# 30041                81  5j1yOqWONR9T6l43AzJ6Es
# 5550                 82  2Xo3rLHjXfdb4avN68aQyi
#
#                                    track_name    track_artist  \
# 23282                One Kiss (with Dua Lipa)   Calvin Harris
# 5953          Beach Ballin' (feat. blackbear)      Yung Pinch
# 5135                          Runaway (U & I)        Galantis
# 8658             Tupac Back (feat. Rick Ross)       Meek Mill
# 20129                 Going Bad (feat. Drake)       Meek Mill
# 747          Mambo No. 5 (A Little Bit of...)        Lou Bega
# 4981                       Lost (Lenno Remix)  Scavenger Hunt
# 345        Daylight (Airbeat One Anthem 2018)           Fluex
# 30041  Tip Toe (feat. A Boogie Wit da Hoodie)     Roddy Ricch
# 5550                BEST ON EARTH (feat. BIA)            Russ
#
#                track_album_id                        track_album_name  \
# 23282  7GEzhoTiqcPYkOprWQu581                One Kiss (with Dua Lipa)
# 5953   1P6UQ3wWvVyFH7Y7cuDu7M         Beach Ballin' (feat. blackbear)
# 5135   4QcXq4vTVN7dFb7bZa9jG2                                Pharmacy
# 8658   1xE3Obhzdpw4aIqPDMf4I4         MMG Presents: Self Made, Vol. 1
# 20129  6UYZEYjpN1DYRW0kqFy9ZE                           Championships
# 747    0F2v1g7RUEmK077TfZGeoS                   Ultimate Holiday Hits
# 4981   0llgzDj4NBSZ4i5dYHJw6d                     Scavenger Hunt - EP
# 345    2Rd9MkQmupPCqDMpHWFapL      Daylight (Airbeat One Anthem 2018)
# 30041  0uyDZAeB7oa8CM6G9PjSOf  Tip Toe (feat. A Boogie Wit da Hoodie)
# 5550   2TBJtc64Y76xWs98Mtko07               BEST ON EARTH (feat. BIA)
#
#       track_album_release_date              playlist_name  \
# 23282               2018-04-06                    Hip pop
# 5953                2020-01-03            Hip-Hop Central
# 5135                2015-06-05            Indie Poptimism
# 8658                2011-05-23       Gangster Rap Workout
# 20129               2018-11-30  Global Top 50 | 2020 Hits
# 747                 2008-07-25             90s Dance Hits
# 4981                2015-01-09           Indie Poptimism!
# 345                 2018-06-22         Pop Warmup 130 BPM
# 30041               2019-11-25         Pop Hits 2000-2019
# 5550                2019-10-18                  RapCaviar
#
#                   playlist_id playlist_genre playlist_subgenre  key  mode
# 23282  1Sc7bobknESH7SXQcnmoX5            r&b           hip pop    9     0
# 5953   37i9dQZF1DWY6tYEFs22tT            rap           hip hop    1     0
# 5135   2QiMewRbSavfZ9MSAYz2h6            pop   indie poptimism    1     1
# 8658   0ZRwrJ2EDGyKR6YgQPWXeO            rap      gangster rap    1     0
# 20129  1KNl4AYfgZtOVm9KHkhPTF          latin     latin hip hop    4     0
# 747    50cXvxgMGrvoUeLhkzCyIO            pop         dance pop    5     0
# 4981   4hKPJNFIhdAg4pAksn78FJ            pop   indie poptimism    0     1
# 345    37i9dQZF1DX3PIAZMcbo2T            pop         dance pop    7     0
# 30041  6mtYuOxzl58vSGnEDtZ9uB            edm           pop edm    1     1
# 5550   37i9dQZF1DX0XUsuxWHRQd            rap           hip hop    5     0

# %%
# title 带 '-' 
df_test_cat[df_test_cat["track_name"].str.contains(r"-", case=False, na=False)].sample(10, random_state=42)
# Out:
#        track_popularity                track_id  \
# 24699                28  6Gfq4pVJVnrsHVxkmFpo09
# 29961                65  0P5lXk4fg0682IgDyK7GFM
# 27755                63  4Sp0jLZN8MgPnoGDufJS7N
# 705                  81  0Cn8NxJZz7zUlsaA3rXoIU
# 26824                69  5JCi3pyggvk4B0yd0BK3ow
# 30332                69  76gCEZkHTzU8lY3aY6mFRM
# 13608                66  4igIYHF3B5VBxEafHauVo3
# 9163                 24  6BX3nIZqQ9Ji0ZK8QCDpCs
# 32385                39  7yklZhCvqV4mWhaWv89hEO
# 20575                30  015ljpgRzoOEwCEST5CGbb
#
#                                               track_name         track_artist  \
# 24699  Make It Last Forever (with Jacci McGhee) - Ext...          Keith Sweat
# 29961                                I'm Blue - Club Mix            Kush Kush
# 27755                       On My Way - Da Tweekaz Remix          Alan Walker
# 705                                         Easy - Remix          Jhay Cortez
# 26824                           Stay High - Habits Remix              Tove Lo
# 30332                            Sumiu do Mapa - Ao Vivo          Lucas Lucco
# 13608               Fat Bottomed Girls - Remastered 2011                Queen
# 9163                                          Call 9-1-1  Westside Connection
# 32385                     Teardrops - Rapless Video Edit        Crew Cardinal
# 20575             Fascination (Re-Recorded / Remastered)            Company B
#
#                track_album_id                         track_album_name  \
# 24699  6GXk2hxl4q5GoPHarlUet8  The Best of Keith Sweat: Make You Sweat
# 29961  785itgCjNtYOiRpu1SIDoo                    I'm Blue (Club Mixes)
# 27755  1ODOCRQWwjfJRqJ34RtrKa             On My Way (Da Tweekaz Remix)
# 705    3Y00aLNDKDq9rXR3cIcbDo                             Easy (Remix)
# 26824  5Z5O36p7BivXzkucc0PAfw                      Queen Of The Clouds
# 30332  5K1DtZURandKZhczQfHAMr       De Bar em Bar (Ao Vivo em Goiânia)
# 13608  21HMAUrbbYSj9NiPPlGumy         Jazz (Deluxe Remastered Version)
# 9163   5CdIIrp4pEVIVEJi5hAk1f          The Best Of Westside Connection
# 32385  7Auv7o5h4h5oOgQUW7hkjK                                Teardrops
# 20575  0uM6dDXnSRPGhmxZonDKqT                   12" Booty Shakin' Hits
#
#       track_album_release_date  \
# 24699               2004-01-13
# 29961               2019-09-13
# 27755               2019-06-25
# 705                 2019-11-19
# 26824               2014-09-24
# 30332               2019-10-18
# 13608               1978-11-10
# 9163                2007-11-30
# 32385               2013-11-29
# 20575               2009-04-01
#
#                                            playlist_name  \
# 24699  Back in the day - R&B, New Jack Swing, Swingbe...
# 29961                             EDM 2020 House & Dance
# 27755                                   Crossfit‏‏​​   ‍
# 705                                          Todo Éxitos
# 26824                                 Electro House 2020
# 30332  Verão 2020 | Pop | Funk | Sertanejo | EDM | To...
# 13608                             Classic Rock Playlist.
# 9163                             Oldschool Gangsta Rap 👑
# 32385           Gym (Melbourne Bounce/Progressive House)
# 20575  80's Freestyle/Disco Dance Party (Set Crossfad...
#
#                   playlist_id playlist_genre          playlist_subgenre  key  \
# 24699  3a9y4eeCJRmG9p4YKfqYIx            r&b             new jack swing    7
# 29961  25ButZrVb1Zj1MJioMs09D            edm                    pop edm    0
# 27755  5GiPRvTccToqwOzkoAcDrY            edm              electro house    1
# 705    2ji5tRQVfnhaX1w9FhmSzk            pop                  dance pop    1
# 26824  317O0e8iWJLClLGDKtieRe            edm              electro house    4
# 30332  5HmZtuuIDMtIy21kylqhx6            edm                    pop edm    7
# 13608  7CESj1xKbxdArRzloygvkl           rock               classic rock    2
# 9163   0t9TeyXE2mWe70JT3YwSoH            rap               gangster rap    2
# 32385  5BqOZpVEqRDfZScvW1QUyA            edm  progressive electro house    6
# 20575  1oReEujyWpQv2OX68BVPPA          latin              latin hip hop   10
#
#        mode
# 24699     1
# 29961     0
# 27755     0
# 705       0
# 26824     0
# 30332     1
# 13608     1
# 9163      0
# 32385     1
# 20575     0

# %% [markdown]
# Same as processing training dataset
#
# 核心：只保留每首歌的main title
#
# 1. 处理 title 带 '-' 的
#
# 2. 处理 title 带 '()'的

# %%
df_test_cat["track_name"] = df_test_cat["track_name"].fillna("")
df_test_cat["track_album_name"] = df_test_cat["track_album_name"].fillna("")

df_test_cat["track_name"] = df_test_cat["track_name"].str.lower() # lowercase song title
df_test_cat["track_name"] = df_test_cat["track_name"].map(lambda x: unidecode(x)) # 处理类英文letter，至英文

print("Number of title with none English letter: ", df_test_cat["track_name"].str.contains(r"[^\x00-\x7F]+", regex=True).sum())
# Out:
# Number of title with none English letter:  0

# %%
# title 带 '-' 的一共 879
process_df = df_test_cat[df_test_cat["track_name"].str.contains(r"-", case=False, na=False)]

print("\n rows: ", process_df.shape[0])
process_df.head()
# Out:
#  rows:  634
#        track_popularity                track_id  \
# 13295                 1  6fZO4Uk2yM4MwrY13n2zBI
# 12325                76  2PzU4IB8Dr6mxV3lHuaG34
# 18115                56  4DCHszO57DZHgvqalfoITR
# 26803                30  3J2gbESlzrz86jonlkE2Qg
# 3931                  3  2sHY6sT0EomTon1pVVLwjF
#
#                                          track_name        track_artist  \
# 13295      (don't fear) the reaper - single version    Blue Öyster Cult
# 12325  (i can't get no) satisfaction - mono version  The Rolling Stones
# 18115                               1973 - acoustic         James Blunt
# 26803                             2020 - radio edit         Chris Burke
# 3931                             2am - matoma remix            Astrid S
#
#                track_album_id        track_album_name  \
# 13295  24atu8BmjlxBrHAS8aWQS1  The Singles Collection
# 12325  2Q5MwpTmtjscaS34mJFXQQ        Out Of Our Heads
# 18115  3obQJSWpREwvi19TTAvM5v      All The Lost Souls
# 26803  35MzwNrVLXOUVoIsBSIiI2                    2020
# 3931   4e9bmpAF2A8gvImxaTUXil           2AM (Remixes)
#
#       track_album_release_date           playlist_name  \
# 13295                     2005  Workday: Rock Classics
# 12325               1965-07-30           Rock Classics
# 18115               2007-09-17        Unplugged Hits 📣
# 26803               2019-12-31      Electro House 2020
# 3931                2015-05-12    Chillout & Remixes 💜
#
#                   playlist_id playlist_genre playlist_subgenre  key  mode
# 13295  37i9dQZF1DX1lwxXvReaux           rock      classic rock    0     1
# 12325  37i9dQZF1DWXRqgorJj26U           rock      classic rock    2     1
# 18115  5NTm3injIRkUMROsZr3C2O          latin         latin pop    9     1
# 26803  317O0e8iWJLClLGDKtieRe            edm     electro house    5     0
# 3931   4NlAd9NpIa92IjErMyAriM            pop   indie poptimism    8     1

# %%
 # '- ... mix ...', '- ... remaster ...', '- ... version ...' , '- ... edit ...'

pattern = r"-.*(mix|remaster|version|edit).*?$"
df_test_cat[df_test_cat["track_name"].str.contains(pattern, case = False, na = False)]
# Out:
# C:\Users\fuyuz\AppData\Local\Temp\ipykernel_13876\3922688978.py:4: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df_test_cat[df_test_cat["track_name"].str.contains(pattern, case = False, na = False)]
#        track_popularity                track_id  \
# 13295                 1  6fZO4Uk2yM4MwrY13n2zBI
# 12325                76  2PzU4IB8Dr6mxV3lHuaG34
# 26803                30  3J2gbESlzrz86jonlkE2Qg
# 3931                  3  2sHY6sT0EomTon1pVVLwjF
# 21327                64  6IoKSUyNOOheJRjiuGb1ew
# ...                 ...                     ...
# 15978                72  36lkJSDyMEZoWTqtRj8Q8q
# 30049                52  3T7ZHIgO30bKeASQppPtM6
# 31127                13  1rP7ICGrYCqWYwB7SnblXd
# 29423                51  7qfZTBNZQqvg0hMamrAQB1
# 19490                67  44DCGBt8P6iZPd0RRsZiMw
#
#                                          track_name        track_artist  \
# 13295      (don't fear) the reaper - single version    Blue Öyster Cult
# 12325  (i can't get no) satisfaction - mono version  The Rolling Stones
# 26803                             2020 - radio edit         Chris Burke
# 3931                             2am - matoma remix            Astrid S
# 21327                                    47 - remix            Anuel AA
# ...                                             ...                 ...
# 15978        you're the inspiration - 2006 remaster             Chicago
# 30049                   young ones - rudelies remix              Avenza
# 31127                      your soul - original mix           Gary Caos
# 29423                    zombie - bassjackers remix               Ran-D
# 19490                      badwine - extended remix                Feid
#
#                track_album_id                              track_album_name  \
# 13295  24atu8BmjlxBrHAS8aWQS1                        The Singles Collection
# 12325  2Q5MwpTmtjscaS34mJFXQQ                              Out Of Our Heads
# 26803  35MzwNrVLXOUVoIsBSIiI2                                          2020
# 3931   4e9bmpAF2A8gvImxaTUXil                                 2AM (Remixes)
# 21327  0uwIB5LyXa2riRyWUwKiJA                                    47 (Remix)
# ...                       ...                                           ...
# 15978  1ICKrl6sDjJD1YdR9VDfPR            Chicago 17 (Expanded & Remastered)
# 30049  7ilK2JYZS3cuHLRbu91JWM  Young Ones (RudeLies Remix) [feat. Johnning]
# 31127  4DbWQ5CLRbo8GwmC2Z1NED                                     Your Soul
# 29423  7DnPC3dlNFBRgoqMPYGswZ                              Zombie (Remixes)
# 19490  33rFXfv76EqEnR1N3qtJW7                      badwine (Extended Remix)
#
#       track_album_release_date  \
# 13295                     2005
# 12325               1965-07-30
# 26803               2019-12-31
# 3931                2015-05-12
# 21327               2017-03-31
# ...                        ...
# 15978               1984-05-14
# 30049               2019-10-11
# 31127               2019-02-15
# 29423               2019-01-11
# 19490               2019-10-18
#
#                                            playlist_name  \
# 13295                             Workday: Rock Classics
# 12325                                      Rock Classics
# 26803                                 Electro House 2020
# 3931                                Chillout & Remixes 💜
# 21327                                         Los Cangri
# ...                                                  ...
# 15978  Rock Ballads 80s 90s | Best Rock Love Songs 80...
# 30049                                 Pop Hits 2000-2019
# 31127                                     Selected House
# 29423                                      Big Room 2019
# 19490                                     Todo Reggaeton
#
#                   playlist_id playlist_genre          playlist_subgenre  key  \
# 13295  37i9dQZF1DX1lwxXvReaux           rock               classic rock    0
# 12325  37i9dQZF1DWXRqgorJj26U           rock               classic rock    2
# 26803  317O0e8iWJLClLGDKtieRe            edm              electro house    5
# 3931   4NlAd9NpIa92IjErMyAriM            pop            indie poptimism    8
# 21327  2hTs6GuPwhmg4ApNqxWXLE          latin              latin hip hop    6
# ...                       ...            ...                        ...  ...
# 15978  0y8MUle9Lf8VDNjPsskzJB           rock                  hard rock   11
# 30049  6mtYuOxzl58vSGnEDtZ9uB            edm                    pop edm    4
# 31127  2JPzPB9jnvJLAYtmCbvZy8            edm  progressive electro house    3
# 29423  6SrHyxIxWfQx9ISEr6yowk            edm                   big room    4
# 19490  4csIMGPI3aGo3Xy7WG8jBi          latin                  reggaeton    1
#
#        mode
# 13295     1
# 12325     1
# 26803     0
# 3931      1
# 21327     1
# ...     ...
# 15978     1
# 30049     0
# 31127     0
# 29423     0
# 19490     1
#
# [529 rows x 13 columns]

# %%
#'- ... mix ...', '- ... remaster ...', '- ... version ...' , '- ... edit ...' 占 带 '-' 的 proportion
print("Proportion of titles that have sub-title in the form of '- ... mix ...', '- ... remaster ...', '- ... version ...' , or '- ... edit ...': ",
      round(df_test_cat[df_test_cat["track_name"].str.contains(pattern, case = False, na = False)].shape[0] / df_test_cat[df_test_cat["track_name"].str.contains(r"-", case=False, na=False)].shape[0], 3)
      )
# Out:
# Proportion of titles that have sub-title in the form of '- ... mix ...', '- ... remaster ...', '- ... version ...' , or '- ... edit ...':  0.834
# C:\Users\fuyuz\AppData\Local\Temp\ipykernel_13876\1810053339.py:3: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   round(df_test_cat[df_test_cat["track_name"].str.contains(pattern, case = False, na = False)].shape[0] / df_test_cat[df_test_cat["track_name"].str.contains(r"-", case=False, na=False)].shape[0], 3)

# %% [markdown]
# 需要特殊处理的一组title

# %%
process_df.loc[~ process_df["track_name"].str.contains(pattern, case = False, na = False)]
# Out:
# C:\Users\fuyuz\AppData\Local\Temp\ipykernel_13876\2356024891.py:1: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   process_df.loc[~ process_df["track_name"].str.contains(pattern, case = False, na = False)]
#        track_popularity                track_id  \
# 18115                56  4DCHszO57DZHgvqalfoITR
# 30370                82  1uryupl9hqVZYurJwH4G9k
# 7880                 18  507rhTuNu5YPpxQTT287Y2
# 13069                43  00MI0oGDVJYM1qWbyUOIhH
# 30358                78  4gDvg62vG96w0qJaF6wzcd
# ...                 ...                     ...
# 14276                32  3rINKmrSbky6jUVEvNtIX8
# 12865                37  0DgevHFzyhzIWN8hzrO98C
# 18566                65  0ePiYPlCq3dhwfAjUttjT2
# 26308                44  6AKoio5a5qRiIK6QvYJJrr
# 26332                30  4twOuEvYNHNUc9dHUqhhUY
#
#                                               track_name         track_artist  \
# 18115                                    1973 - acoustic          James Blunt
# 30370                                3 batidas - ao vivo   Guilherme & Benuto
# 7880                                         30's-n-lows          Bass Patrol
# 13069                                   867-5309 / jenny         Tommy Tutone
# 30358  a culpa e do meu grau (feat. ze neto & cristia...  Diego & Victor Hugo
# ...                                                  ...                  ...
# 14276     you're in the army now - status quo in concert           Status Quo
# 12865                                  young lust - live         Roger Waters
# 18566                          el era perfecto - en vivo           María José
# 26308                                     reidei*buru-su          LUCKY TAPES
# 26332                   Lian niNi rete -crazy about you-         Junko Ohashi
#
#                track_album_id                               track_album_name  \
# 18115  3obQJSWpREwvi19TTAvM5v                             All The Lost Souls
# 30370  2s2XNO2C38JP3NVOp8zkm4                            3 Batidas (Ao Vivo)
# 7880   6LcsgWx1N0HZHlVLgdZw7N                              The Kings Of Bass
# 13069  6lqQzf2MGsTQ577cGXIfcK                               867-5309 / Jenny
# 30358  2lmLfahVMp5C3w9HW5TxbL  Diego & Victor Hugo Ao Vivo em Brasília - EP1
# ...                       ...                                            ...
# 14276  5Nx780igKtyoLCLAxPorqE                                Live At The BBC
# 12865  5iokLBTiQQAh5zdUdsj3Gp                          Roger Waters The Wall
# 18566  3hBpaFjb8x2JvzTvEdaf5J                             Conexión (En Vivo)
# 26308  42eeqAnEc2zjh8ND4IrVb6                            CIGARETTE & ALCOHOL
# 26332  10BIzys0QO4l9UQGay0iRI                 THE BEST SONGS of JUNKO OHASHI
#
#       track_album_release_date  \
# 18115               2007-09-17
# 30370               2019-08-16
# 7880                      2004
# 13069               2008-04-09
# 30358               2019-03-22
# ...                        ...
# 14276               2010-01-01
# 12865               2015-11-20
# 18566               2019-06-07
# 26308               2016-07-06
# 26332                     1998
#
#                                            playlist_name  \
# 18115                                   Unplugged Hits 📣
# 30370  Verão 2020 | Pop | Funk | Sertanejo | EDM | To...
# 7880                                Minitruckin Playlist
# 13069                                 80s / Classic Rock
# 30358  Verão 2020 | Pop | Funk | Sertanejo | EDM | To...
# ...                                                  ...
# 14276                                     Permanent Wave
# 12865                               Classic Rock Legends
# 18566                      Exitos 2020 - Latin Billboard
# 26308                   Japanese Funk/Soul/NEO/Jazz/Acid
# 26332                   Japanese Funk/Soul/NEO/Jazz/Acid
#
#                   playlist_id playlist_genre playlist_subgenre  key  mode
# 18115  5NTm3injIRkUMROsZr3C2O          latin         latin pop    9     1
# 30370  5HmZtuuIDMtIy21kylqhx6            edm           pop edm    8     1
# 7880   0VVH2Nzj6kBVGK3WIUQMAw            rap  southern hip hop    1     1
# 13069  29dTrOurPDrMcrnio2q6hZ           rock      classic rock    2     1
# 30358  5HmZtuuIDMtIy21kylqhx6            edm           pop edm    6     1
# ...                       ...            ...               ...  ...   ...
# 14276  6dqoVI7qwYLyNqbg0MPad3           rock    permanent wave    4     0
# 12865  3NcxM1LJJdua8AcRxtijNY           rock      classic rock    2     1
# 18566  0k2IDDkcVyIpIgE6d1woDM          latin         latin pop    8     1
# 26308  4zNayWuATXCAA9gaXvnFnq            r&b          neo soul    2     0
# 26332  4zNayWuATXCAA9gaXvnFnq            r&b          neo soul    5     0
#
# [105 rows x 13 columns]

# %% [markdown]
# 这些 index 是需要独立处理的

# %%
process_special_idx_lis = [13069, 25834, 11401, 9779, 6039, 5638, 8045, 12649, 26710, 26308, 10643, 7231, 397, 18497, 16481,
                           14874, 7880, 9163, 26332, 7822, 17235, 26362, 13943, 25752, 8958, 4634, 32459
                           ]
len(process_special_idx_lis)

#remove_idx = [8958, 32459]
remove_idx = [8958, 32459, 26362, 13943, 25752, 4634]
process_special_idx_lis = pd.Series(process_special_idx_lis)
process_special_idx_lis = process_special_idx_lis[~process_special_idx_lis.isin(remove_idx)].tolist()

# %%
process_df_sub = process_df[process_df["track_name"].str.contains(pattern, case = False, na = False)] # 直接去掉 ‘-’, row 741
process_df_sub_1 = process_df.loc[~ process_df["track_name"].str.contains(pattern, case = False, na = False)] # 需特地处理, row 138
# Out:
# C:\Users\fuyuz\AppData\Local\Temp\ipykernel_13876\3104508494.py:1: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   process_df_sub = process_df[process_df["track_name"].str.contains(pattern, case = False, na = False)] # 直接去掉 ‘-’, row 741
# C:\Users\fuyuz\AppData\Local\Temp\ipykernel_13876\3104508494.py:2: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   process_df_sub_1 = process_df.loc[~ process_df["track_name"].str.contains(pattern, case = False, na = False)] # 需特地处理, row 138

# %% [markdown]
# 处理 741 row 的部分，直接去掉 含'-'后面的内容

# %%
process_df_sub
# Out:
#        track_popularity                track_id  \
# 13295                 1  6fZO4Uk2yM4MwrY13n2zBI
# 12325                76  2PzU4IB8Dr6mxV3lHuaG34
# 26803                30  3J2gbESlzrz86jonlkE2Qg
# 3931                  3  2sHY6sT0EomTon1pVVLwjF
# 21327                64  6IoKSUyNOOheJRjiuGb1ew
# ...                 ...                     ...
# 15978                72  36lkJSDyMEZoWTqtRj8Q8q
# 30049                52  3T7ZHIgO30bKeASQppPtM6
# 31127                13  1rP7ICGrYCqWYwB7SnblXd
# 29423                51  7qfZTBNZQqvg0hMamrAQB1
# 19490                67  44DCGBt8P6iZPd0RRsZiMw
#
#                                          track_name        track_artist  \
# 13295      (don't fear) the reaper - single version    Blue Öyster Cult
# 12325  (i can't get no) satisfaction - mono version  The Rolling Stones
# 26803                             2020 - radio edit         Chris Burke
# 3931                             2am - matoma remix            Astrid S
# 21327                                    47 - remix            Anuel AA
# ...                                             ...                 ...
# 15978        you're the inspiration - 2006 remaster             Chicago
# 30049                   young ones - rudelies remix              Avenza
# 31127                      your soul - original mix           Gary Caos
# 29423                    zombie - bassjackers remix               Ran-D
# 19490                      badwine - extended remix                Feid
#
#                track_album_id                              track_album_name  \
# 13295  24atu8BmjlxBrHAS8aWQS1                        The Singles Collection
# 12325  2Q5MwpTmtjscaS34mJFXQQ                              Out Of Our Heads
# 26803  35MzwNrVLXOUVoIsBSIiI2                                          2020
# 3931   4e9bmpAF2A8gvImxaTUXil                                 2AM (Remixes)
# 21327  0uwIB5LyXa2riRyWUwKiJA                                    47 (Remix)
# ...                       ...                                           ...
# 15978  1ICKrl6sDjJD1YdR9VDfPR            Chicago 17 (Expanded & Remastered)
# 30049  7ilK2JYZS3cuHLRbu91JWM  Young Ones (RudeLies Remix) [feat. Johnning]
# 31127  4DbWQ5CLRbo8GwmC2Z1NED                                     Your Soul
# 29423  7DnPC3dlNFBRgoqMPYGswZ                              Zombie (Remixes)
# 19490  33rFXfv76EqEnR1N3qtJW7                      badwine (Extended Remix)
#
#       track_album_release_date  \
# 13295                     2005
# 12325               1965-07-30
# 26803               2019-12-31
# 3931                2015-05-12
# 21327               2017-03-31
# ...                        ...
# 15978               1984-05-14
# 30049               2019-10-11
# 31127               2019-02-15
# 29423               2019-01-11
# 19490               2019-10-18
#
#                                            playlist_name  \
# 13295                             Workday: Rock Classics
# 12325                                      Rock Classics
# 26803                                 Electro House 2020
# 3931                                Chillout & Remixes 💜
# 21327                                         Los Cangri
# ...                                                  ...
# 15978  Rock Ballads 80s 90s | Best Rock Love Songs 80...
# 30049                                 Pop Hits 2000-2019
# 31127                                     Selected House
# 29423                                      Big Room 2019
# 19490                                     Todo Reggaeton
#
#                   playlist_id playlist_genre          playlist_subgenre  key  \
# 13295  37i9dQZF1DX1lwxXvReaux           rock               classic rock    0
# 12325  37i9dQZF1DWXRqgorJj26U           rock               classic rock    2
# 26803  317O0e8iWJLClLGDKtieRe            edm              electro house    5
# 3931   4NlAd9NpIa92IjErMyAriM            pop            indie poptimism    8
# 21327  2hTs6GuPwhmg4ApNqxWXLE          latin              latin hip hop    6
# ...                       ...            ...                        ...  ...
# 15978  0y8MUle9Lf8VDNjPsskzJB           rock                  hard rock   11
# 30049  6mtYuOxzl58vSGnEDtZ9uB            edm                    pop edm    4
# 31127  2JPzPB9jnvJLAYtmCbvZy8            edm  progressive electro house    3
# 29423  6SrHyxIxWfQx9ISEr6yowk            edm                   big room    4
# 19490  4csIMGPI3aGo3Xy7WG8jBi          latin                  reggaeton    1
#
#        mode
# 13295     1
# 12325     1
# 26803     0
# 3931      1
# 21327     1
# ...     ...
# 15978     1
# 30049     0
# 31127     0
# 29423     0
# 19490     1
#
# [529 rows x 13 columns]

# %%
def strip_leading_paren(title: str) -> str:
    cleaned = re.sub(r"^\s*\([^)]*\)\s*", "", title)
    return cleaned


def clean_title_part_1(column): # pd df column, 替换 '-' to ''

    column = column.str.replace(r"\s*-\s*.*$", "", regex=True)
    column = column.map(strip_leading_paren) # 先去掉 () 在开头的title
    column = column.str.replace("'", "")
    column = column.str.replace(r"\s*\(.*$", "", regex=True) # 去掉 ( 以及后面的内容
    column = column.str.replace(r"\*\*[^*]*\*\*", "", regex=True) # 去掉 ** ... **
    column = column.str.replace(r"[?.,'&`]", "", regex=True) #  去除 ? , . ' & ` 
    column = column.str.replace("feat", "", regex=False)
    column = column.str.replace(r"[!:]$", "", regex=True) # 去掉紧跟的 ! 和 :, : 匹配不到
    column = column.str.replace(r"!", "", regex=True)
    column = column.str.replace(r"\s*\[[^\]]*\]", "", regex=True) # 移除 [...]
    column = column.str.replace(r"#", "", regex=True) # 移除 #number

    column = column.str.replace(r"\s{2,}", " ", regex=True) # 两步把多余空格压成一个

    column = column.str.strip()

    return column

process_df_sub.loc[:, "track_name"] = clean_title_part_1(process_df_sub.loc[:, "track_name"])

# %% [markdown]
# 分为 special 和 non-special

# %%
process_df_sub_1_special = process_df_sub_1.loc[process_special_idx_lis] # row 27
process_df_sub_1_non_special = process_df_sub_1.loc[~ process_df_sub_1.index.isin(process_special_idx_lis)] # row 111

# %% [markdown]
# 处理 special

# %%
process_df_sub_1_special.loc[7231, "track_name"] = process_df_sub_1_special.loc[7231, "track_name"].replace("---", "uck")
process_df_sub_1_special.loc[397, "track_name"] = process_df_sub_1_special.loc[397, "track_name"].replace("-", "")
process_df_sub_1_special.loc[9163, "track_name"] = process_df_sub_1_special.loc[9163, "track_name"].replace("-", "")
def clean_title_part_2(column): # pd df column, 替换 '-' to ''
    column = column.str.replace("-", " ")
    column = column.str.replace(r"'s\b", "", regex=True) # "'s\b" 用单词边界确保只命中真正的缩写，不会误删 songs 里的 s。
    column = column.str.replace(r"[:*]", " ", regex=True)
    column = column.str.replace(r"[,.'/]", "", regex=True) #  去除 ( ) ? , . 
    column = column.str.replace(r"\s{2,}", " ", regex=True) # 两步把多余空格压成一个
    column = column.str.strip()

    return column

process_df_sub_1_special.loc[:,"track_name"] = clean_title_part_2(process_df_sub_1_special.loc[:,"track_name"])

# %% [markdown]
# 处理 non-special

# %%
def clean_title_part_3(column): # pd df column, 替换 '-' to ''

    column = column.str.replace(r"\s*-\s*.*$", "", regex=True)
    column = column.str.replace("'", "")
    column = column.str.replace(r"\s*\(.*$", "", regex=True) # 去掉 ( 以及后面的内容
    column = column.str.replace(r"[?.,'&!]", "", regex=True) #  去除 ? , . ' & 
    column = column.str.replace(r"\s{2,}", " ", regex=True) # 两步把多余空格压成一个
    column = column.str.strip()

    return column

process_df_sub_1_non_special.loc[:,"track_name"] = clean_title_part_3(process_df_sub_1_non_special.loc[:,"track_name"])

# %% [markdown]
# 转移到 process_df

# %%
process_df.loc[process_df_sub.index, "track_name"] = process_df_sub["track_name"]
process_df.loc[process_df_sub_1_special.index, "track_name"] = process_df_sub_1_special["track_name"]
process_df.loc[process_df_sub_1_non_special.index, "track_name"] = process_df_sub_1_non_special["track_name"]

df_test_cat.loc[process_df.index, "track_name"] = process_df["track_name"] #转移到 df_train_cat

# %%
pattern = r"[^\w\s]"  # 非字母数字、非空白的字符
punctu_lis = df_test_cat.loc[~ df_test_cat["track_name"].str.contains(r"[()]", regex=True), "track_name"].str.findall(pattern).explode().unique()
punctu_lis = punctu_lis[1:]
punctu_lis
# Out:
# array(["'", nan, '.', '/', '?', ',', '$', ':', '&', '!', '@', '+', '*',
#        '[', ']'], dtype=object)

# %%
def clean_title_part_4(column): # pd df column, 替换 '-' to ''

    column = column.map(strip_leading_paren) # 先去掉 () 在开头的title
    #column = column.str.replace(r"\(([A-Za-z])\)", r"\1", regex=True) # d(r)own to drown
    column = column.str.replace(r"\s*\([^)]*\)", "", regex=True) # 去掉 (...) 以及后面的内容
    column = column.str.replace(r"\s*&[^)]*\)$", ")", regex=True) # 去掉特殊的一行 & ...
    column = column.str.replace(r"[)]+$", "", regex=True) # 去掉 () 残余
    column = column.str.replace(r"'s\b", "", regex=True) # "'s\b" 用单词边界确保只命中真正的缩写，不会误删 songs 里的 s。
    
    column = column.str.replace(r"\s*\[[^\]]*\]", "", regex=True) # 移除 [...]
    column = column.str.replace("feat.", "", regex=False)
    
    #column = column.str.replace(r"\s*\[.*$", "", regex=True) # 移除残留 [...
    column = column.str.replace("'", "")
    column = column.str.replace(r"[?.!,&%+`\":~|<>=]", "", regex=True) #  去除 ? . ! , & % + " : ~ | < >
    column = column.str.replace(r"[/]", " ", regex=True) 
    column = column.str.replace(r"#\d+", "", regex=True) # 去除 # + 数字 e.g. #1, #2, ...
    column = column.str.replace("#", "", regex=False) 

    column = column.str.replace(r"\s{2,}", " ", regex=True) # 两步把多余空格压成一个
    column = column.str.strip()

    return column

df_test_cat.loc[:, "track_name"] = clean_title_part_4(df_test_cat.loc[:, "track_name"])

# %%
df_test_cat.loc[~ df_test_cat["track_name"].str.contains(r"[()]", regex=True), "track_name"].str.findall(pattern).explode().unique()
# Out:
# array([nan, '$', '@', '*'], dtype=object)

# %% [markdown]
# 处理 $

# %%
df_test_cat.loc[df_test_cat["track_name"].str.contains("$", regex=False), "track_name"]
# Out:
# 22266              $100
# 6148     $ave dat money
# 21524         a$ian boy
# 29477              ca$h
# 6328           no tru$t
# Name: track_name, dtype: object

# %%
#mask = [6328, 29477, 6148, 21524, 3128]
mask = [6328, 29477, 6148, 21524]
df_test_cat.loc[mask, "track_name"] = df_test_cat.loc[mask, "track_name"].str.replace("$", "s", regex=False)

df_test_cat.loc[22266, "track_name"] = df_test_cat.loc[22266, "track_name"].replace("$", "")

# %% [markdown]
# 处理 *

# %%
process_df = df_test_cat[df_test_cat["track_name"].str.contains("*", regex=False)]

# %%
process_df.loc[7348, "track_name"] = re.sub(r"\*\*", "gg", process_df.loc[7348, "track_name"])
process_df.loc[8639, "track_name"] = re.sub(r"\*\*", "uc", process_df.loc[8639, "track_name"])
process_df.loc[8762, "track_name"] = re.sub(r"\*\*\*\*", "igga", process_df.loc[8762, "track_name"])
process_df.loc[26334, "track_name"] = process_df.loc[26334, "track_name"].replace("*", " ")
process_df.loc[26328, "track_name"] = process_df.loc[26328, "track_name"].replace("*", " ")
process_df.loc[8085, "track_name"] = re.sub(r"\*\*", "gg", process_df.loc[8085, "track_name"])
process_df.loc[26320, "track_name"] = process_df.loc[26320, "track_name"].replace("*", " ")
#process_df.loc[9693, "track_name"] = process_df.loc[9693, "track_name"].replace("*", "")
#process_df.loc[5407, "track_name"] = process_df.loc[5407, "track_name"].replace("*", "")
#process_df.loc[26427, "track_name"] = process_df.loc[26427, "track_name"].replace("*", "")

process_df.loc[:,"track_name"] = process_df.loc[:,"track_name"].str.replace(r"\s{2,}", " ", regex=True) # 两步把多余空格压成一个
process_df.loc[:,"track_name"] = process_df.loc[:,"track_name"].str.strip()

df_test_cat.loc[process_df.index, "track_name"] = process_df["track_name"] #转移到 df_test_cat

# %% [markdown]
# 处理@

# %%
#df_test_cat.loc[1827, "track_name"] = df_test_cat.loc[1827, "track_name"].replace("@", "")

df_test_cat.loc[:,"track_name"] = df_test_cat.loc[:,"track_name"].str.replace(r"\s{2,}", " ", regex=True) # 两步把多余空格压成一个
df_test_cat.loc[:,"track_name"] = df_test_cat.loc[:,"track_name"].str.strip()

# %% [markdown]
# ### 2. Album name

# %%
df_test_cat.loc[:, "track_album_name"] = df_test_cat.loc[:, "track_album_name"].str.lower()
df_test_cat.loc[:, "track_album_name"] = df_test_cat.loc[:, "track_album_name"].map(lambda x: unidecode(x))

print("Number of album name with none English letter: ", df_test_cat["track_album_name"].str.contains(r"[^\x00-\x7F]+", regex=True).sum())
# Out:
# Number of album name with none English letter:  0

# %%
pattern = r"[^\w\s]" 
punctu_lis = df_test_cat["track_album_name"].str.findall(pattern).explode().unique()
#punctu_lis = punctu_lis[1:]
punctu_lis
# Out:
# array(['#', '(', ')', nan, "'", '.', '-', '&', ':', ',', '[', ']', '/',
#        '!', '$', '"', '?', '=', '@', '+', '`', '*', '<', '>', '%', '|'],
#       dtype=object)

# %%
def clean_album_name(column): # pd df column, 替换 '-' to ''

    column = column.map(strip_leading_paren) # 先去掉 () 在开头的title
    column = column.str.replace(r"\s*\([^)]*\)", "", regex=True) # 去掉 (...) 以及后面的内容
    column = column.str.replace(r"'s\b", "", regex=True)
    column = column.str.replace(r"\s*\(.*$", "", regex=True) # 去掉 (... 残留
    column = column.str.replace(r"\s*\[[^\]]*\]", "", regex=True) # 移除 [...]
    column = column.str.replace(r"\s*\[.*$", "", regex=True) # 移除 [... 残留
    #column = column.str.replace(r"\s*remix\)\s*$", "", regex=True) # 去掉 remix)

    column = column.str.replace(r"(?<=\b[A-Za-z])\.(?=[A-Za-z]\b)", "", regex=True) # 多一步处理 . , 处理 r.o.s.e 这样的
    column = column.str.replace(r"[-:>/.]", " ", regex=True)
    column = column.str.replace(r'''[?!,'"%+`~|<>{}=)]''', "", regex=True)
    column = column.str.replace(r"#\d+", "", regex=True) # 去除 # + 数字 e.g. #1, #2, ...
    column = column.str.replace("#", "", regex=False) 

    column = column.str.replace(r"\s{2,}", " ", regex=True) # 两步把多余空格压成一个
    column = column.str.strip()

    return column

df_test_cat.loc[:, "track_album_name"] = clean_album_name(df_test_cat.loc[:, "track_album_name"])

# %%
df_test_cat.loc[:, "track_album_name"].str.findall(pattern).explode().unique()
# Out:
# array([nan, '&', '$', '@', '*'], dtype=object)

# %% [markdown]
# $ *
#
# 专门处理 &
#
# @ 保留

# %% [markdown]
# 处理 &，只保留 r&b

# %%
mask = df_test_cat["track_album_name"].str.contains(r"(?i)r&b", regex=True)

df_test_cat.loc[~mask, "track_album_name"] = (
df_test_cat.loc[~mask, "track_album_name"]
       .str.replace("&", " ", regex=False)
     .str.replace(r"\s{2,}", " ", regex=True)
        .str.strip()
)

# %% [markdown]
# 处理 $, 换成 s

# %%
#mask = [24662, 29477, 21524, 8317, 8317, 9929, 6087, 9926]
#mask = [29477, 21524, 8317, 8317, 9929, 6087, 9926]
mask = [29477, 21524, 8317, 8317, 9929, 6087]
df_test_cat.loc[mask, "track_album_name"] = df_test_cat.loc[mask, "track_album_name"].str.replace("$", "s", regex=False)

df_test_cat.loc[23943, "track_album_name"] = df_test_cat.loc[23943, "track_album_name"].replace("b4 da $$", "bad ass")

# %% [markdown]
# 处理 *

# %%
process_df = df_test_cat[df_test_cat["track_album_name"].str.contains("*", regex=False)]

process_df.loc[7348, "track_album_name"] = re.sub(r"\*\*", "gg", process_df.loc[7348, "track_album_name"])
process_df.loc[8762, "track_album_name"] = re.sub(r"\*\*\*\*", "igga", process_df.loc[8762, "track_album_name"])
process_df.loc[26328, "track_album_name"] = process_df.loc[26328, "track_album_name"].replace("*", " ")
process_df.loc[9040, "track_album_name"] = re.sub(r"\*\*\*", "igg", process_df.loc[9040, "track_album_name"])
#process_df.loc[5407, "track_album_name"] = process_df.loc[5407, "track_album_name"].replace("*", "")
#process_df.loc[26427, "track_album_name"] = process_df.loc[26427, "track_album_name"].replace("*", "")

process_df.loc[:,"track_album_name"] = process_df.loc[:,"track_album_name"].str.replace(r"\s{2,}", " ", regex=True) # 两步把多余空格压成一个
process_df.loc[:,"track_album_name"] = process_df.loc[:,"track_album_name"].str.strip()

df_test_cat.loc[process_df.index, "track_album_name"] = process_df["track_album_name"] #转移到 df_test_cat

# %% [markdown]
# ### 3. genre and sub-genre

# %%
def clean_genre(column): # 确保没有多余的空格

    column = column.str.replace(r"[-]", " ", regex = True) # 对 sub genre

    column = column.str.replace(r"\s{2,}", " ", regex=True) # 两步把多余空格压成一个
    column = column.str.strip()

    return column

df_test_cat.loc[:, "playlist_genre"] = clean_genre(df_test_cat.loc[:, "playlist_genre"])
df_test_cat.loc[:, "playlist_subgenre"] = clean_genre(df_test_cat.loc[:, "playlist_subgenre"])

# %% [markdown]
# ## Concatenate All the Texts

# %%
text_cols = df_test_cat.columns[[2, 5, 9, 10]]

for i in text_cols:
    print(f"{i} na number: ", df_test_cat[i].isna().sum())
print("")
for i in text_cols:
    print(f"0 length string in {i}: ", 0 in df_test_cat[i].str.len().values)
# Out:
# track_name na number:  0
# track_album_name na number:  0
# playlist_genre na number:  0
# playlist_subgenre na number:  0
#
# 0 length string in track_name:  True
# 0 length string in track_album_name:  True
# 0 length string in playlist_genre:  False
# 0 length string in playlist_subgenre:  False

# %%
df_test_cat["combined_text"] = (df_test_cat[text_cols].agg(" ".join, axis=1) # str concatenate
                                 .str.replace(r"\s{2,}", " ", regex=True)
                                 .str.strip())

# %% [markdown]
# ## Output

# %%
df_test_cat.to_csv("dataset/df_test_cat_rs_42_processed.csv", index=True, encoding="utf-8")

# %% [markdown]
# # Validation dataset

# %%
df_validate_cat = pd.read_csv("dataset/df_validate_cat_rs_42.csv", index_col=0)
df_validate_num = pd.read_csv("dataset/df_validate_num_rs_42.csv", index_col=0)

df_validate_cat = pd.concat([df_validate_num.iloc[:, 0], df_validate_cat], axis=1)

# %%
mask = df_validate_cat.groupby("track_name")["track_popularity"].idxmax()
df_validate_cat = df_validate_cat.loc[mask]

# %% [markdown]
# ## Text Cleaning

# %% [markdown]
# ### 1. Song Title

# %%
# title 结尾带 (...)
# title 结尾带 (... feat ...) 是 # title 结尾带 (...) 的 subset
process_df = df_validate_cat[df_validate_cat["track_name"].str.contains(r"\([^()]*\)\s*$", na=False)]
process_df
# Out:
#        track_popularity                track_id  \
# 7283                 26  0I7EJmk6S47mpVh73dB02r
# 16728                70  0EdgK7ASb4kfRkW8pVMN02
# 4350                 64  4DAaQ5InUO23d8yNRbB0Yj
# 2550                  9  0Wv5wuenRLI3BcwgT3HPIP
# 18039                26  5t5v3w3RWdwDLJ7pqti9Kk
# ...                 ...                     ...
# 9383                 35  4JGypFKEHrlufSjF8DPl9X
# 2641                 51  3Iqbhajo4nRQJU7ThH77Rt
# 2379                 84  0Ryd8975WihbObpp5cPW1t
# 8678                 22  1Elr2krap8BHDCofTxr4FH
# 9515                 19  2Bf669lDRfdfSiznO1bb7V
#
#                                             track_name   track_artist  \
# 7283   1st & 10 (Featuring Infamous 2-0 & Fate Wilson)       Ludacris
# 16728                        2 Hearts (feat. Gia Koka)      Sam Feldt
# 4350                      6's to 9's (feat. Rationale)       Big Wild
# 2550                       A Different Way (with Lauv)       DJ Snake
# 18039                  A Escondidas (feat. Jessi Leon)          Bonka
# ...                                                ...            ...
# 9383                             Yeah Ya Know (Takers)           T.I.
# 2641                      You Remind Me (feat. Stanaj)        Gryffin
# 2379                     boyfriend (with Social House)  Ariana Grande
# 8678                   Гагарин (feat. Каспийский груз)        Advaita
# 9515                              Свобода (Feat Alesh)         Simaga
#
#                track_album_id  \
# 7283   2kT80DHqRtHQzDhQ2RCoIV
# 16728  798RdmwmE3IZcZnW0jT7kc
# 4350   7LZAgsQQr0cm61SmUdgKlz
# 2550   4urwuJbStO1K5ph63U7AZv
# 18039  5JQIT6JvMHDXzXeHWytfTy
# ...                       ...
# 9383   1GBhTm8ndgzGhw1jD7dFcK
# 2641   4VOj6KgAaOqAUS9bp6z6jp
# 2379   3zVB99XMdbP9HTVNg0GJwV
# 8678   0dsmBtZ16GMKcRMfKzdUA1
# 9515   1OoiP2BJKkSG4N9qHHJ6C1
#
#                                       track_album_name  \
# 7283                           Back For The First Time
# 16728                        2 Hearts (feat. Gia Koka)
# 4350                                        Superdream
# 2550                       A Different Way (with Lauv)
# 18039                                     MÁs Que Ayer
# ...                                                ...
# 9383   We Run This, Vol. 5 (mixed by Mr. E of RPS Fam)
# 2641                                     Gravity Pt. 1
# 2379                                         boyfriend
# 8678                                       Контрольный
# 9515                                            Миражи
#
#       track_album_release_date                       playlist_name  \
# 7283                2000-01-01  90s-2000s Southern Hip Hop / Crunk
# 16728               2020-01-10          Tropical House 🏝 2020 Hits
# 4350                2019-02-01             2019 in Indie Poptimism
# 2550                2017-09-21          Electropop Hits  2017-2020
# 18039               2015-07-07                   Latin Pop antiguo
# ...                        ...                                 ...
# 9383                2010-12-03                         RAP Gangsta
# 2641                2018-12-14                     Electropop 2019
# 2379                2019-08-02                       post teen pop
# 8678                2015-07-31                Russian Gangster Rap
# 9515                2015-03-03                RUSSIAN Gangster Rap
#
#                   playlist_id playlist_genre playlist_subgenre  key  mode
# 7283   5wsWBmQgDtKa8CEg7wTEMi            rap  southern hip hop    9     1
# 16728  2SRbIs0eBQwHeTP7kErjwo          latin          tropical    7     1
# 4350   16RNbqnNCCLlBJti7JU5nc            pop   indie poptimism    8     1
# 2550   7kyvBmlc1uSqsTL0EuNLrx            pop        electropop    8     1
# 18039  4BmnnqWEQAamNoVjtjrQJP          latin         latin pop    5     1
# ...                       ...            ...               ...  ...   ...
# 9383   1Z1gW89x4MSBjkvVjGg7DQ            rap      gangster rap    1     1
# 2641   4Bi8VLtaSu0JILliif8lH6            pop        electropop    3     0
# 2379   3kvwJXPULhSUalL6ykJbn5            pop     post-teen pop   10     0
# 8678   0u0qLLE8MZc679RZWCk1TT            rap      gangster rap    5     0
# 9515   0Jw0HckkxCfIrOvpN081eV            rap      gangster rap    2     1
#
# [433 rows x 13 columns]

# %%
# title 带 '-' 
df_validate_cat[df_validate_cat["track_name"].str.contains(r"-", case=False, na=False)]
# Out:
#        track_popularity                track_id  \
# 7283                 26  0I7EJmk6S47mpVh73dB02r
# 14255                56  0uJyE3M3ecGZgzltsQKs3a
# 31421                 9  6lheVNyIjiezy9IgLfWqq6
# 18176                54  2WXTF0qgKbczC2O8VymeLO
# 17868                17  3T5QSIgoaPIh07SwixRDp7
# ...                 ...                     ...
# 9996                 72  7KksdXBhdufqWDxGxyt4I7
# 9983                 74  7gRPkCEa3YMaxET5ZYT7Ni
# 30354                60  4v6SAnzwEr7s2m0gFQnJFJ
# 27025                11  6jHeunClv5nFVXQ6jtnaWm
# 9458                 18  5cDO8fIEgNUT2bMlWvrQnH
#
#                                               track_name  \
# 7283     1st & 10 (Featuring Infamous 2-0 & Fate Wilson)
# 14255                     A Design for Life - Remastered
# 31421      A Million Lights - feat. Zoë Badwi [Original]
# 18176  A Sky Full of Stars - Live at the Royal Albert...
# 17868                                    A Solas - Remix
# ...                                                  ...
# 9996                              no14 - feat. Dani Faiv
# 9983                      occh1 purpl3 - feat. Marracash
# 30354                        Áudio - Ao Vivo em Brasília
# 27025                                 Étude post-baroque
# 9458                                           Май 45-го
#
#                  track_artist          track_album_id  \
# 7283                 Ludacris  2kT80DHqRtHQzDhQ2RCoIV
# 14255  Manic Street Preachers  3jvKfPU4A2j7tVOFkhcEi2
# 31421           Grant Smillie  1keHPlXQTCd2dIVD8K7yRE
# 18176                Coldplay  1hNS0RsxPTFjmKXCgmjSLS
# 17868                   Lunay  4kkZsCc8FiqMmq1sLBk6Na
# ...                       ...                     ...
# 9996              tha Supreme  42wflBbrb9OchJfd3qiGRO
# 9983              tha Supreme  42wflBbrb9OchJfd3qiGRO
# 30354     Diego & Victor Hugo  6PlcH8kJmbJIagbWVuqHz7
# 27025                    Nhyx  7xyLot8qvUDna1e1VyY8Jj
# 9458               StaFFord63  6XMf8HgW12QA6Xlb64KVF7
#
#                                   track_album_name track_album_release_date  \
# 7283                       Back For The First Time               2000-01-01
# 14255  Everything Must Go 10th Anniversary Edition               1996-05-20
# 31421           A Million Lights (feat. Zoë Badwi)               2012-09-07
# 18176                      Ghost Stories Live 2014               2014-11-21
# 17868                                A Solas Remix               2018-12-07
# ...                                            ...                      ...
# 9996                                       23 6451               2019-11-15
# 9983                                       23 6451               2019-11-15
# 30354      Diego & Victor Hugo Ao Vivo em Brasília               2019-07-12
# 27025                                       Zéphyr               2020-01-17
# 9458                                     Май 45-го               2019-05-03
#
#                                            playlist_name  \
# 7283                  90s-2000s Southern Hip Hop / Crunk
# 14255                                     Permanent Wave
# 31421                                        Vocal House
# 18176                                   Unplugged Hits 📣
# 17868                 LATIN POP 2020 🔥 Pop latino actual
# ...                                                  ...
# 9996                                           Zona Trap
# 9983                                           Zona Trap
# 30354  Verão 2020 | Pop | Funk | Sertanejo | EDM | To...
# 27025                         Electro Posé - Discoveries
# 9458                                RUSSIAN Gangster Rap
#
#                   playlist_id playlist_genre          playlist_subgenre  key  \
# 7283   5wsWBmQgDtKa8CEg7wTEMi            rap           southern hip hop    9
# 14255  5glAD13obyL0G9SH9ukBz2           rock             permanent wave    0
# 31421  5PCAWKfUWAUj8VeY8G7xRQ            edm  progressive electro house    9
# 18176  5NTm3injIRkUMROsZr3C2O          latin                  latin pop    6
# 17868  2kKzN3kRYDzBctlaWs7CP2          latin                  latin pop    6
# ...                       ...            ...                        ...  ...
# 9996   37i9dQZF1DWXU2naFUn37x            rap                       trap   10
# 9983   37i9dQZF1DWXU2naFUn37x            rap                       trap    2
# 30354  5HmZtuuIDMtIy21kylqhx6            edm                    pop edm   11
# 27025  6nZaTh6K1SwhdELFTmA99C            edm              electro house    2
# 9458   0Jw0HckkxCfIrOvpN081eV            rap               gangster rap    9
#
#        mode
# 7283      1
# 14255     1
# 31421     1
# 18176     1
# 17868     0
# ...     ...
# 9996      0
# 9983      1
# 30354     1
# 27025     1
# 9458      0
#
# [668 rows x 13 columns]

# %% [markdown]
# Same as processing training dataset
#
# 核心：只保留每首歌的main title
#
# 1. 处理 title 带 '-' 的
#
# 2. 处理 title 带 '()'的

# %%
df_validate_cat["track_name"] = df_validate_cat["track_name"].fillna("")
df_validate_cat["track_album_name"] = df_validate_cat["track_album_name"].fillna("")

df_validate_cat["track_name"] = df_validate_cat["track_name"].str.lower() # lowercase song title
df_validate_cat["track_name"] = df_validate_cat["track_name"].map(lambda x: unidecode(x)) # 处理类英文letter，至英文

print("Number of title with none English letter: ", df_validate_cat["track_name"].str.contains(r"[^\x00-\x7F]+", regex=True).sum())
# Out:
# Number of title with none English letter:  0

# %%
# title 带 '-' 的一共 670
process_df = df_validate_cat[df_validate_cat["track_name"].str.contains(r"-", case=False, na=False)]

print("\n rows: ", process_df.shape[0])
process_df
# Out:
#  rows:  670
#        track_popularity                track_id  \
# 7283                 26  0I7EJmk6S47mpVh73dB02r
# 14255                56  0uJyE3M3ecGZgzltsQKs3a
# 31421                 9  6lheVNyIjiezy9IgLfWqq6
# 18176                54  2WXTF0qgKbczC2O8VymeLO
# 17868                17  3T5QSIgoaPIh07SwixRDp7
# ...                 ...                     ...
# 30354                60  4v6SAnzwEr7s2m0gFQnJFJ
# 27025                11  6jHeunClv5nFVXQ6jtnaWm
# 9458                 18  5cDO8fIEgNUT2bMlWvrQnH
# 26338                30  1DWfjSM4lKBjg7hQLwYkr2
# 1028                 42  2VzUh85tCLAZeOoOJ70ecg
#
#                                               track_name  \
# 7283     1st & 10 (featuring infamous 2-0 & fate wilson)
# 14255                     a design for life - remastered
# 31421      a million lights - feat. zoe badwi [original]
# 18176  a sky full of stars - live at the royal albert...
# 17868                                    a solas - remix
# ...                                                  ...
# 30354                        audio - ao vivo em brasilia
# 27025                                 etude post-baroque
# 9458                                           mai 45-go
# 26338                              hitoXia notapesutori-
# 1028                                       supagetsutei-
#
#                  track_artist          track_album_id  \
# 7283                 Ludacris  2kT80DHqRtHQzDhQ2RCoIV
# 14255  Manic Street Preachers  3jvKfPU4A2j7tVOFkhcEi2
# 31421           Grant Smillie  1keHPlXQTCd2dIVD8K7yRE
# 18176                Coldplay  1hNS0RsxPTFjmKXCgmjSLS
# 17868                   Lunay  4kkZsCc8FiqMmq1sLBk6Na
# ...                       ...                     ...
# 30354     Diego & Victor Hugo  6PlcH8kJmbJIagbWVuqHz7
# 27025                    Nhyx  7xyLot8qvUDna1e1VyY8Jj
# 9458               StaFFord63  6XMf8HgW12QA6Xlb64KVF7
# 26338             Tomoko Aran  7fa6VpNPvW2DVbtohJ0x44
# 1028          AYA A.K.A PANDA  0WcqzetDPl3Q7pfQHEooFe
#
#                                   track_album_name track_album_release_date  \
# 7283                       Back For The First Time               2000-01-01
# 14255  Everything Must Go 10th Anniversary Edition               1996-05-20
# 31421           A Million Lights (feat. Zoë Badwi)               2012-09-07
# 18176                      Ghost Stories Live 2014               2014-11-21
# 17868                                A Solas Remix               2018-12-07
# ...                                            ...                      ...
# 30354      Diego & Victor Hugo Ao Vivo em Brasília               2019-07-12
# 27025                                       Zéphyr               2020-01-17
# 9458                                     Май 45-го               2019-05-03
# 26338                                         浮遊空間                     1983
# 1028                                       スパゲッティー               2019-01-16
#
#                                            playlist_name  \
# 7283                  90s-2000s Southern Hip Hop / Crunk
# 14255                                     Permanent Wave
# 31421                                        Vocal House
# 18176                                   Unplugged Hits 📣
# 17868                 LATIN POP 2020 🔥 Pop latino actual
# ...                                                  ...
# 30354  Verão 2020 | Pop | Funk | Sertanejo | EDM | To...
# 27025                         Electro Posé - Discoveries
# 9458                                RUSSIAN Gangster Rap
# 26338                   Japanese Funk/Soul/NEO/Jazz/Acid
# 1028                       Best of 2019 Dance Pop: Japan
#
#                   playlist_id playlist_genre          playlist_subgenre  key  \
# 7283   5wsWBmQgDtKa8CEg7wTEMi            rap           southern hip hop    9
# 14255  5glAD13obyL0G9SH9ukBz2           rock             permanent wave    0
# 31421  5PCAWKfUWAUj8VeY8G7xRQ            edm  progressive electro house    9
# 18176  5NTm3injIRkUMROsZr3C2O          latin                  latin pop    6
# 17868  2kKzN3kRYDzBctlaWs7CP2          latin                  latin pop    6
# ...                       ...            ...                        ...  ...
# 30354  5HmZtuuIDMtIy21kylqhx6            edm                    pop edm   11
# 27025  6nZaTh6K1SwhdELFTmA99C            edm              electro house    2
# 9458   0Jw0HckkxCfIrOvpN081eV            rap               gangster rap    9
# 26338  4zNayWuATXCAA9gaXvnFnq            r&b                   neo soul   10
# 1028   37i9dQZF1DXdOtZGKonFlM            pop                  dance pop    9
#
#        mode
# 7283      1
# 14255     1
# 31421     1
# 18176     1
# 17868     0
# ...     ...
# 30354     1
# 27025     1
# 9458      0
# 26338     1
# 1028      0
#
# [670 rows x 13 columns]

# %%
 # '- ... mix ...', '- ... remaster ...', '- ... version ...' , '- ... edit ...'

pattern = r"-.*(mix|remaster|version|edit).*?$"
df_validate_cat[df_validate_cat["track_name"].str.contains(pattern, case = False, na = False)]
# Out:
# C:\Users\fuyuz\AppData\Local\Temp\ipykernel_13876\178732232.py:4: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df_validate_cat[df_validate_cat["track_name"].str.contains(pattern, case = False, na = False)]
#        track_popularity                track_id  \
# 14255                56  0uJyE3M3ecGZgzltsQKs3a
# 17868                17  3T5QSIgoaPIh07SwixRDp7
# 8514                 48  6Uw77XfBxwg7VX6mMdqAmT
# 18717                38  3IH2zs1TSPFA2Iy7e5HCmT
# 12158                35  6nnH5zeFZOH3HMpEOG5DLg
# ...                 ...                     ...
# 28286                62  3bmbNLqSJjGDRbbqlJUt4y
# 27865                50  6R9MD6OD2EGOTnblzvi3mw
# 15654                32  3PPJVaa7maBPrYA4OS6gyG
# 17327                11  0W5SiYQOGUsgpmL86KkPJz
# 12183                41  1hQ02BkTnR0BNs3SAznttM
#
#                                 track_name            track_artist  \
# 14255       a design for life - remastered  Manic Street Preachers
# 17868                      a solas - remix                   Lunay
# 8514   arrogant american freestyle - remix               Riff Raff
# 18717                     ace - radio edit                  Rewind
# 12158    action this day - remastered 2011                   Queen
# ...                                    ...                     ...
# 28286   your body - cat dealers radio edit                Tom Novy
# 27865        your mind - will clarke remix              Adam Beyer
# 15654       ziggy stardust - 1997 remaster             David Bowie
# 17327                     zipolite - remix                 Zilvano
# 12183            zoom - remasterizado 2007             Soda Stereo
#
#                track_album_id  \
# 14255  3jvKfPU4A2j7tVOFkhcEi2
# 17868  4kkZsCc8FiqMmq1sLBk6Na
# 8514   7wzqmeAHlPmQBcoEaB8TTg
# 18717  68rUoEpgweglqsBF4fOSRp
# 12158  6reTSIf5MoBco62rk8T7Q1
# ...                       ...
# 28286  5gCptfTCvRbWxTp10t1Yt0
# 27865  6bk7IZwVsHrcoJi94rGuyN
# 15654  3htuY0OiwfkMfM6NJCRyrI
# 17327  6oklpW9cdzpRpdGyz6w4cf
# 12183  3QTxxZucih0hympCczXXuO
#
#                                         track_album_name  \
# 14255        Everything Must Go 10th Anniversary Edition
# 17868                                      A Solas Remix
# 8514                 ARROGANT AMERiCAN FREESTYLE (REMIX)
# 18717                                                Ace
# 12158                          Hot Space (2011 Remaster)
# ...                                                  ...
# 28286  Your Body (feat. Michael Marshall) [Cat Dealer...
# 27865                                    A-Sides, Vol. 8
# 15654                    The Best Of David Bowie 1969-74
# 17327                                   Zipolite (Remix)
# 12183                              El Ultimo Concierto A
#
#       track_album_release_date  \
# 14255               1996-05-20
# 17868               2018-12-07
# 8514                2020-01-10
# 18717               2019-10-13
# 12158               1982-05-03
# ...                        ...
# 28286               2017-07-28
# 27865               2019-09-23
# 15654               1997-10-27
# 17327               2020-01-10
# 12183               1997-10-09
#
#                                            playlist_name  \
# 14255                                     Permanent Wave
# 17868                 LATIN POP 2020 🔥 Pop latino actual
# 8514                                        Gangster Rap
# 18717                                         Great Pops
# 12158                The Queen - La Discografia Completa
# ...                                                  ...
# 28286  🔊BASSBOOSTED🔊⚡ELECTRO HOUSE⚡🔥EDM CAR MUSIC2018...
# 27865                               💊ELECTRO-HOUSE-TECH💊
# 15654                                  Classic Hard Rock
# 17327                                   Paraíso Tropical
# 12183                  Soda Stereo – El Ultimo Concierto
#
#                   playlist_id playlist_genre playlist_subgenre  key  mode
# 14255  5glAD13obyL0G9SH9ukBz2           rock    permanent wave    0     1
# 17868  2kKzN3kRYDzBctlaWs7CP2          latin         latin pop    6     0
# 8514   5joQabz9ys3XPGbSx5CaKv            rap      gangster rap    1     0
# 18717  5SO7xYih5w8X5FEpKvU7Rt          latin         latin pop    1     1
# 12158  3E88dLx4fgFYY70gdGzdnB           rock        album rock    2     1
# ...                       ...            ...               ...  ...   ...
# 28286  4GSiiL8tcMgvoV7K1IADb8            edm     electro house    9     1
# 27865  0AFYmoSuoMQiGGjzvBwr6u            edm     electro house    7     1
# 15654  1gAeQGQ7hr2q7IYmaejDW6           rock         hard rock    7     1
# 17327  2v41efarffe6iY8qpMK5Gj          latin          tropical    9     1
# 12183  3opIxv3Y5GmXDNpbLFZxIm           rock        album rock    4     1
#
# [570 rows x 13 columns]

# %%
#'- ... mix ...', '- ... remaster ...', '- ... version ...' , '- ... edit ...' 占 带 '-' 的 proportion
print("Proportion of titles that have sub-title in the form of '- ... mix ...', '- ... remaster ...', '- ... version ...' , or '- ... edit ...': ",
      round(df_validate_cat[df_validate_cat["track_name"].str.contains(pattern, case = False, na = False)].shape[0] / df_validate_cat[df_validate_cat["track_name"].str.contains(r"-", case=False, na=False)].shape[0], 3)
      )
# Out:
# Proportion of titles that have sub-title in the form of '- ... mix ...', '- ... remaster ...', '- ... version ...' , or '- ... edit ...':  0.851
# C:\Users\fuyuz\AppData\Local\Temp\ipykernel_13876\2389126187.py:3: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   round(df_validate_cat[df_validate_cat["track_name"].str.contains(pattern, case = False, na = False)].shape[0] / df_validate_cat[df_validate_cat["track_name"].str.contains(r"-", case=False, na=False)].shape[0], 3)

# %% [markdown]
# 需要特殊处理的一组title

# %%
process_df.loc[~ process_df["track_name"].str.contains(pattern, case = False, na = False)]
# Out:
# C:\Users\fuyuz\AppData\Local\Temp\ipykernel_13876\2356024891.py:1: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   process_df.loc[~ process_df["track_name"].str.contains(pattern, case = False, na = False)]
#        track_popularity                track_id  \
# 7283                 26  0I7EJmk6S47mpVh73dB02r
# 31421                 9  6lheVNyIjiezy9IgLfWqq6
# 18176                54  2WXTF0qgKbczC2O8VymeLO
# 7592                 48  6cnufgF6qLJGZT2PRFZBr1
# 23505                17  4muAGMNipTEtIoYfMa9QL0
# ...                 ...                     ...
# 30354                60  4v6SAnzwEr7s2m0gFQnJFJ
# 27025                11  6jHeunClv5nFVXQ6jtnaWm
# 9458                 18  5cDO8fIEgNUT2bMlWvrQnH
# 26338                30  1DWfjSM4lKBjg7hQLwYkr2
# 1028                 42  2VzUh85tCLAZeOoOJ70ecg
#
#                                               track_name         track_artist  \
# 7283     1st & 10 (featuring infamous 2-0 & fate wilson)             Ludacris
# 31421      a million lights - feat. zoe badwi [original]        Grant Smillie
# 18176  a sky full of stars - live at the royal albert...             Coldplay
# 7592                               ain't i - main voc up            Yung L.A.
# 23505        amsterdam - recorded at spotify studios nyc      Mandolin Orange
# ...                                                  ...                  ...
# 30354                        audio - ao vivo em brasilia  Diego & Victor Hugo
# 27025                                 etude post-baroque                 Nhyx
# 9458                                           mai 45-go           StaFFord63
# 26338                              hitoXia notapesutori-          Tomoko Aran
# 1028                                       supagetsutei-      AYA A.K.A PANDA
#
#                track_album_id                         track_album_name  \
# 7283   2kT80DHqRtHQzDhQ2RCoIV                  Back For The First Time
# 31421  1keHPlXQTCd2dIVD8K7yRE       A Million Lights (feat. Zoë Badwi)
# 18176  1hNS0RsxPTFjmKXCgmjSLS                  Ghost Stories Live 2014
# 7592   4wCjej94XDH2kKIc6vBqbI                                  Ain't I
# 23505  774yLThHwXXqrrH2bgF912                          Spotify Singles
# ...                       ...                                      ...
# 30354  6PlcH8kJmbJIagbWVuqHz7  Diego & Victor Hugo Ao Vivo em Brasília
# 27025  7xyLot8qvUDna1e1VyY8Jj                                   Zéphyr
# 9458   6XMf8HgW12QA6Xlb64KVF7                                Май 45-го
# 26338  7fa6VpNPvW2DVbtohJ0x44                                     浮遊空間
# 1028   0WcqzetDPl3Q7pfQHEooFe                                  スパゲッティー
#
#       track_album_release_date  \
# 7283                2000-01-01
# 31421               2012-09-07
# 18176               2014-11-21
# 7592                2008-01-01
# 23505               2018-04-04
# ...                        ...
# 30354               2019-07-12
# 27025               2020-01-17
# 9458                2019-05-03
# 26338                     1983
# 1028                2019-01-16
#
#                                            playlist_name  \
# 7283                  90s-2000s Southern Hip Hop / Crunk
# 31421                                        Vocal House
# 18176                                   Unplugged Hits 📣
# 7592                       The Sound of Southern Hip Hop
# 23505                                   Bluegrass Covers
# ...                                                  ...
# 30354  Verão 2020 | Pop | Funk | Sertanejo | EDM | To...
# 27025                         Electro Posé - Discoveries
# 9458                                RUSSIAN Gangster Rap
# 26338                   Japanese Funk/Soul/NEO/Jazz/Acid
# 1028                       Best of 2019 Dance Pop: Japan
#
#                   playlist_id playlist_genre          playlist_subgenre  key  \
# 7283   5wsWBmQgDtKa8CEg7wTEMi            rap           southern hip hop    9
# 31421  5PCAWKfUWAUj8VeY8G7xRQ            edm  progressive electro house    9
# 18176  5NTm3injIRkUMROsZr3C2O          latin                  latin pop    6
# 7592   18jT9NMRZifv6cMtK2jWD4            rap           southern hip hop   11
# 23505  37i9dQZF1DX56crgoe4TG3            r&b                    hip pop    0
# ...                       ...            ...                        ...  ...
# 30354  5HmZtuuIDMtIy21kylqhx6            edm                    pop edm   11
# 27025  6nZaTh6K1SwhdELFTmA99C            edm              electro house    2
# 9458   0Jw0HckkxCfIrOvpN081eV            rap               gangster rap    9
# 26338  4zNayWuATXCAA9gaXvnFnq            r&b                   neo soul   10
# 1028   37i9dQZF1DXdOtZGKonFlM            pop                  dance pop    9
#
#        mode
# 7283      1
# 31421     1
# 18176     1
# 7592      1
# 23505     1
# ...     ...
# 30354     1
# 27025     1
# 9458      0
# 26338     1
# 1028      0
#
# [100 rows x 13 columns]

# %% [markdown]
# 这些 index 是需要独立处理的

# %%
process_special_idx_lis = [32459, 22334, 442, 6992, 26097, 8185, 7197, 14435, 9775, 16932, 30791, 5259, 27025, 9458
                           ]
len(process_special_idx_lis)

#remove_idx = [8958, 32459]
#remove_idx = [8958, 32459, 26362, 13943, 25752, 4634]
#process_special_idx_lis = pd.Series(process_special_idx_lis)
#process_special_idx_lis = process_special_idx_lis[~process_special_idx_lis.isin(remove_idx)].tolist()
# Out:
# 14

# %%
process_df_sub = process_df[process_df["track_name"].str.contains(pattern, case = False, na = False)] # 直接去掉 ‘-’, row 570
process_df_sub_1 = process_df.loc[~ process_df["track_name"].str.contains(pattern, case = False, na = False)] # 需特地处理, row 100
# Out:
# C:\Users\fuyuz\AppData\Local\Temp\ipykernel_13876\1236612678.py:1: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   process_df_sub = process_df[process_df["track_name"].str.contains(pattern, case = False, na = False)] # 直接去掉 ‘-’, row 570
# C:\Users\fuyuz\AppData\Local\Temp\ipykernel_13876\1236612678.py:2: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   process_df_sub_1 = process_df.loc[~ process_df["track_name"].str.contains(pattern, case = False, na = False)] # 需特地处理, row 100

# %% [markdown]
# 处理 570 row 的部分，直接去掉 含'-'后面的内容

# %%
process_df_sub.loc[:, "track_name"] = clean_title_part_1(process_df_sub.loc[:, "track_name"])

# %% [markdown]
# 分为 special 和 non-special

# %%
process_df_sub_1_special = process_df_sub_1.loc[process_special_idx_lis] # row 27
process_df_sub_1_non_special = process_df_sub_1.loc[~ process_df_sub_1.index.isin(process_special_idx_lis)] # row 111

# %% [markdown]
# 处理 special

# %%
process_df_sub_1_special.loc[:,"track_name"] = clean_title_part_2(process_df_sub_1_special.loc[:,"track_name"])

# %% [markdown]
# 处理 non-special

# %%
process_df_sub_1_non_special.loc[:,"track_name"] = clean_title_part_3(process_df_sub_1_non_special.loc[:,"track_name"])

# %% [markdown]
# 转移到 process_df

# %%
process_df.loc[process_df_sub.index, "track_name"] = process_df_sub["track_name"]
process_df.loc[process_df_sub_1_special.index, "track_name"] = process_df_sub_1_special["track_name"]
process_df.loc[process_df_sub_1_non_special.index, "track_name"] = process_df_sub_1_non_special["track_name"]

df_validate_cat.loc[process_df.index, "track_name"] = process_df["track_name"] #转移到 df_train_cat

# %%
pattern = r"[^\w\s]"  # 非字母数字、非空白的字符
punctu_lis = df_validate_cat.loc[~ df_validate_cat["track_name"].str.contains(r"[()]", regex=True), "track_name"].str.findall(pattern).explode().unique()
punctu_lis = punctu_lis[1:]
punctu_lis
# Out:
# array(['$', '.', "'", nan, '%', ':', '/', '!', '[', ']', ',', '"', '&',
#        '?', '*', '+', '|', '<', '>'], dtype=object)

# %%
df_validate_cat.loc[:, "track_name"] = clean_title_part_4(df_validate_cat.loc[:, "track_name"])

# %%
df_validate_cat.loc[~ df_validate_cat["track_name"].str.contains(r"[()]", regex=True), "track_name"].str.findall(pattern).explode().unique()
# Out:
# array([nan, '$', '*'], dtype=object)

# %% [markdown]
# 处理 $

# %%
df_validate_cat.loc[df_validate_cat["track_name"].str.contains("$", regex=False), "track_name"]
# Out:
# 21143    $ a n t e r i a
# 10595             $enhor
# 29206          a$ian boy
# 21664     bernice burgo$
# 10448              fre$h
# 22276                 m$
# Name: track_name, dtype: object

# %%
#mask = [6328, 29477, 6148, 21524, 3128]
mask = [10595, 29206, 21664, 10448, 22276, 21143]
df_validate_cat.loc[mask, "track_name"] = df_validate_cat.loc[mask, "track_name"].str.replace("$", "s", regex=False)

df_validate_cat.loc[21143, "track_name"] = df_validate_cat.loc[21143, "track_name"].replace(" ", "")

# %% [markdown]
# 处理 *

# %%
process_df = df_validate_cat[df_validate_cat["track_name"].str.contains("*", regex=False)]

# %%
process_df
# Out:
#        track_popularity                track_id               track_name  \
# 28754                29  0B5GzF48NCJ4ltvBLpVcLi                     f*ck
# 9353                 68  49zD0wr2S3d0lZPib0K4e1      f*ck up some commas
# 7936                  1  45kgqsq1g9liM5tvdKNhLa  f*ckwithmeyouknowigotit
# 28032                42  6nlCPdygwRryI79rUbWx4m        let get f*cked up
# 31178                32  7d6c9PjkpsKnLOGPkeeBFU            what the f**k
#
#       track_artist          track_album_id  \
# 28754  Bassjackers  5AVczO9dRt4JKMvQhDSCh2
# 9353        Future  0fUy6IdLHDpGNwavIlhEsl
# 7936         JAY-Z  37uqAKt9dLsLob7yomDWY4
# 28032         MAKJ  15JJXzr7hNE4sdUmpBgRiQ
# 31178  Fatboy Slim  6L6QL2oG9BCvZcjPc1e3V3
#
#                             track_album_name track_album_release_date  \
# 28754  F*CK (Dimitri Vegas & Like Mike Edit)               2016-06-10
# 9353                            DS2 (Deluxe)               2015-07-17
# 7936               Magna Carta... Holy Grail               2013-07-10
# 28032                    Let's Get F*cked Up               2014-03-17
# 31178                   Best of the Bootlegs               2010-09-13
#
#                                            playlist_name  \
# 28754                              BIG-ROOM NEVER DIES !
# 9353                                         RAP Gangsta
# 7936                                      Hip-Hop 'n RnB
# 28032  Fitness Workout Electro | House | Dance | Prog...
# 31178                                     Selected House
#
#                   playlist_id playlist_genre          playlist_subgenre  key  \
# 28754  4QtO2XySphMOJt7pX0yaVi            edm                   big room    9
# 9353   1Z1gW89x4MSBjkvVjGg7DQ            rap               gangster rap   11
# 7936   0275i1VNfBnsNbPl0QIBpG            rap           southern hip hop   10
# 28032  6KnQDwp0syvhfHOR4lWP7x            edm              electro house    0
# 31178  2JPzPB9jnvJLAYtmCbvZy8            edm  progressive electro house    7
#
#        mode
# 28754     0
# 9353      0
# 7936      0
# 28032     1
# 31178     1

# %%
process_df.loc[28754, "track_name"] = process_df.loc[28754, "track_name"].replace("*", "u")
process_df.loc[9353, "track_name"] = process_df.loc[9353, "track_name"].replace("*", "u")
process_df.loc[7936, "track_name"] = process_df.loc[7936, "track_name"].replace("*", "u")
process_df.loc[28032, "track_name"] = process_df.loc[28032, "track_name"].replace("*", "u")
process_df.loc[31178, "track_name"] = re.sub(r"\*\*", "uc", process_df.loc[31178, "track_name"])

process_df.loc[:,"track_name"] = process_df.loc[:,"track_name"].str.replace(r"\s{2,}", " ", regex=True) # 两步把多余空格压成一个
process_df.loc[:,"track_name"] = process_df.loc[:,"track_name"].str.strip()

df_validate_cat.loc[process_df.index, "track_name"] = process_df["track_name"] #转移到 df_validate_cat

# %% [markdown]
# 处理@

# %%
df_validate_cat["track_name"].str.contains('*', regex=False).sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### 2. Album name

# %%
df_validate_cat.loc[:, "track_album_name"] = df_validate_cat.loc[:, "track_album_name"].str.lower()
df_validate_cat.loc[:, "track_album_name"] = df_validate_cat.loc[:, "track_album_name"].map(lambda x: unidecode(x))

print("Number of album name with none English letter: ", df_validate_cat["track_album_name"].str.contains(r"[^\x00-\x7F]+", regex=True).sum())
# Out:
# Number of album name with none English letter:  0

# %%
pattern = r"[^\w\s]" 
punctu_lis = df_validate_cat["track_album_name"].str.findall(pattern).explode().unique()
#punctu_lis = punctu_lis[1:]
punctu_lis
# Out:
# array(['#', nan, '(', ')', '[', '.', ',', '&', ']', "'", '/', '!', '?',
#        '-', '$', '"', ':', '+', '=', '*', '~', '%', '`', '{', '}', ';',
#        '<', '>'], dtype=object)

# %%
df_validate_cat.loc[:, "track_album_name"] = clean_album_name(df_validate_cat.loc[:, "track_album_name"])

# %%
df_validate_cat.loc[:, "track_album_name"].str.findall(pattern).explode().unique()
# Out:
# array([nan, '$', '&', '*'], dtype=object)

# %% [markdown]
# $ *
#
# 专门处理 &

# %%
mask = df_validate_cat["track_album_name"].str.contains(r"(?i)r&b", regex=True)

df_validate_cat.loc[~mask, "track_album_name"] = (
df_validate_cat.loc[~mask, "track_album_name"]
       .str.replace("&", " ", regex=False)
     .str.replace(r"\s{2,}", " ", regex=True)
        .str.strip()
)

# %% [markdown]
# 处理 $, 换成 s

# %%
mask = [29206, 8315, 21664, 10448, 9935, 22276]
df_validate_cat.loc[mask, "track_album_name"] = df_validate_cat.loc[mask, "track_album_name"].str.replace("$", "s", regex=False)

# %% [markdown]
# 处理 *

# %%
process_df = df_validate_cat[df_validate_cat["track_album_name"].str.contains("*", regex=False)]

process_df.loc[28754, "track_album_name"] = re.sub(r"\*", "u", process_df.loc[28754, "track_album_name"])
process_df.loc[28032, "track_album_name"] = re.sub(r"\*", "u", process_df.loc[28032, "track_album_name"])

process_df.loc[:,"track_album_name"] = process_df.loc[:,"track_album_name"].str.replace(r"\s{2,}", " ", regex=True) # 两步把多余空格压成一个
process_df.loc[:,"track_album_name"] = process_df.loc[:,"track_album_name"].str.strip()

df_validate_cat.loc[process_df.index, "track_album_name"] = process_df["track_album_name"] #转移到 df_validate_cat

# %% [markdown]
# ### 3. genre and sub-genre

# %%
df_validate_cat.loc[:, "playlist_genre"] = clean_genre(df_validate_cat.loc[:, "playlist_genre"])
df_validate_cat.loc[:, "playlist_subgenre"] = clean_genre(df_validate_cat.loc[:, "playlist_subgenre"])

# %% [markdown]
# ## Concatenate All the Texts

# %%
text_cols = df_validate_cat.columns[[2, 5, 9, 10]]

for i in text_cols:
    print(f"{i} na number: ", df_validate_cat[i].isna().sum())
print("")
for i in text_cols:
    print(f"0 length string in {i}: ", 0 in df_validate_cat[i].str.len().values)
# Out:
# track_name na number:  0
# track_album_name na number:  0
# playlist_genre na number:  0
# playlist_subgenre na number:  0
#
# 0 length string in track_name:  False
# 0 length string in track_album_name:  True
# 0 length string in playlist_genre:  False
# 0 length string in playlist_subgenre:  False

# %%
df_validate_cat["combined_text"] = (df_validate_cat[text_cols].agg(" ".join, axis=1) # str concatenate
                                 .str.replace(r"\s{2,}", " ", regex=True)
                                 .str.strip())

# %% [markdown]
# ## Output

# %%
df_validate_cat.to_csv("dataset/df_validate_cat_rs_42_processed.csv", index=True, encoding="utf-8")
